# %% [markdown]
# -----------------------------------------------------------------------------
#
#  NOTE: Provide the script that covers all questions between the START/END tags
#        at the end of the file. No separate START/END tags for each question.
#        Add comments to explain each step.
#
#
#  QUESTION 1 (10 points)
#  -----------------------------------------------------
#  For this assignment we will use a dataset of laptop
#  company price list. The dataset provides a snapshot of
#  laptop pricing and not the whole picture.
#  Meaning, the dataset has both new and existing laptops with prices
#  based on the existing company. Download the dataset from the
#  assignment page. Here is a quick overview of the dataset columns:
#
#    company:Laptop Manufacturer
#    product: Brand and Model
#    typename: Type (Notebook, Ultrabook, Gaming, etc.)
#    inches: Numeric- Screen Size
#    screen/resolution: Screen Resolution
#    cpu: Central Processing Unit (CPU)
#    ram: Laptop RAM
# 	 memory: Hard Disk / SSD Memory
#    gpu: Graphics Processing Units (GPU)
#    opsys: Operating System
# 	 weight: Laptop Weight
# 	 price_euros: Price (Euro)
#  You will notice that there can be multiple prices per product, each
#  one recorded on a separate row.
#
#  Design an appropriate 3NF relational schema. Provide either the Python or the R code that
#  connects to the database and creates all necessary tables as per the 3NF relational schema you designed
#  Note: (you may use either uni_small or uni_large database, or create your own new database using pgAdmin)
#  Note: (you should create more than one table).
#
#  Important:
#  In your CREATE TABLE statements you must provide data types AND
#  primary/foreign keys (as applicable to relate your schemas).
#
#  NOTE: All actions must be performed in your either Python or R code. No points if the database
#        tables are created manually in pgAdmin and not with either Python or R code.
#
#  Make sure your code has no errors.
#  When grading, we will run your script and see all the appropriate tables are created in the database properly.
#
#
# 	SCORING RUBRIC
# 	**************
# 	1 points: Necessary packages are imported. Necessary database connections are made.
# 	4 points: All necessary tables for 3NF are defined.
# 	3 points: All tables has correct PK/FK as appropriate, and all columns has correct data type,
# 					relevant columns has appropriate NULL / NOT NULL constraints defined.
# 	2 points: Simply copy/pasting and executing the script provided in answer-1
# 				creates all tables successfully in the database without any error
# 				*1 minor (but only syntax) error will still get you 1 point

# %%
import pandas as pd
from sqlalchemy import create_engine

conn_url = "postgresql://postgres:123456@localhost/postgres"

engine = create_engine(conn_url)

Connection = engine.connect()

create_company = """
    CREATE TABLE company (
      company_id int NOT NULL,
      company_name varchar(255) NOT NULL,
      CONSTRAINT "company_pkey" PRIMARY KEY (company_id)
    ) ;
"""

create_product = """
    CREATE TABLE product (
        product_id int NOT NULL,
        "Product_name" varchar(255) NOT NULL,
        "Product_model" varchar(255) NOT NULL,
        "TypeName" varchar(255) DEFAULT NULL,
        "Inches" double precision NOT NULL,
        "ScreenResolution" varchar(255) DEFAULT NULL,
        "Cpu" varchar(255) DEFAULT NULL,
        "Ram" varchar(255) DEFAULT NULL,
        "HDD"	varchar(255) DEFAULT NULL,
        "SSD"	varchar(255) DEFAULT NULL,
        "Flash_Storage" varchar(255) DEFAULT NULL,
        "Memory" varchar(255) DEFAULT NULL,
        "Gpu" varchar(255) DEFAULT NULL,
        "OpSys" varchar(255) DEFAULT NULL,
        "Weight" varchar(255) NOT NULL,
        "Price_euros" double precision NOT NULL,
        CONSTRAINT "product_pkey" PRIMARY KEY (product_id)
    );
"""

create_company_have_product = """
    CREATE TABLE company_have_product (
          company_id int NOT NULL,
          product_id int NOT NULL,
          CONSTRAINT "company_have_product_pkey" PRIMARY KEY (company_id,product_id),
          CONSTRAINT "company_have_product_fkey_company" FOREIGN KEY (company_id) REFERENCES company (company_id),
          CONSTRAINT "company_have_product_fkey_product" FOREIGN KEY (product_id) REFERENCES product (product_id)
    );
"""

# %% [markdown]
# execute

# %%
Connection.execute(create_company)
Connection.execute(create_product)
Connection.execute(create_company_have_product)

# %% [markdown]
#  QUESTION 2 (20 points)
#  ------------------------
#  Provide the either Python or R code that populates the database with the data from the
#  provided "HW6_DATA.csv" file. You can download the dataset
#  from the assignment page. It is anticipated that you will perform several steps
#  of data processing in Python or R in order to extract, transform and load all data from
#  the file to the database tables. Manual transformations in a spreadsheet, or
#  similar, are not acceptable, all work must be done in either Python or R. Make sure your code
#  has no errors, no partial credit for code that returns errors. When grading,
#  we will run your script and see all the appropriate data is inserted in correct tables in the database.
#
# 	SCORING RUBRIC
# 	**************
# 	2 points: Necessary packages are imported. Necessary database connections are made.
# 	1 points: Code is reading / loading correct data file without any error.
# 	8 points: All 3NF tables are loaded correctly with correct data.
# 	4 points: Brand and Model in Product are split into individual columns and are transformed correctly
# 			  to load in appropriate 3NF table relevant columns has appropriate NULL / NOT NULL constraints defined.
# 	2 points: Apropriate PK values are generated and loaded into tables correctly
# 	3 points: Simply copy/pasting and executing the script provided in answer-2
# 				loads all the data successfully in the appropriate tables without any error
# 			  *1 minor (but only syntax) error will still get you 1 point

# %% [markdown]
# Data Process

# %%
# load  the data
data = pd.read_csv("laptop_price.csv", encoding='ISO-8859-1')

# Split Brand and Model
lst = ['Product']
name = []
model = []
for cName in lst:
    c = data[cName]
    for i in c:
        temp = i.split(" ")
        i_inverse = i[::-1]
        index = len(i) - i_inverse.index(' ')
        name.append(i[:index - 1])
        model.append(i[index:len(i)])
    column_name = data.columns.values.tolist()
    data.insert(loc=column_name.index(cName) + 1, column=cName + '_model', value=model)
    data.insert(loc=column_name.index(cName) + 1, column=cName + '_name', value=name)
    # data=data.drop(cName,axis=1)
    name.clear()
    model.clear()
# Split HDD , SSD, and Flash_Storage
HDD = []
SSD = []
Flash_Storage = []
c = data["Memory"]

for i in c:
    temp = i.split(" ")
    temp_set = {'HDD': '0', 'SSD': '0', 'Flash_Storage': '0'}
    for k in range(0, len(temp)):
        if temp[k] == 'HDD':
            temp_set['HDD'] = temp[k - 1]
        elif temp[k] == 'SSD':
            temp_set['SSD'] = temp[k - 1]
        elif temp[k] == 'Flash':
            temp_set['Flash_Storage'] = temp[k - 1]
        else:
            pass
    HDD.append(temp_set['HDD'])
    SSD.append(temp_set['SSD'])
    Flash_Storage.append(temp_set['Flash_Storage'])
column_name = data.columns.values.tolist()
data.insert(loc=column_name.index("Memory") + 1, column='Flash_Storage', value=Flash_Storage)
data.insert(loc=column_name.index("Memory") + 1, column='SSD', value=SSD)
data.insert(loc=column_name.index("Memory") + 1, column='HDD', value=HDD)
# Extract company table and save company ID and name with dictionary
company_set = {}
company = data[['Company']]
company = company.drop_duplicates(subset={'Company'})
company.index = list(range(len(company.index)))
company.insert(loc=0, column='company_id', value=list(range(len(company.index))))
for i in company.values:
    company_set[i[1]] = i[0]
company.rename(columns={'Company': 'company_name'}, inplace=True)
# Extract product table
product = data[['Company', 'Product', 'Product_name', 'Product_model',
                'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
                'HDD', 'SSD', 'Flash_Storage', 'Memory', 'Gpu', 'OpSys', 'Weight',
                'Price_euros']]
product = product.drop_duplicates(subset={'Company', 'Product', 'Product_name', 'Product_model',
                                          'TypeName', 'Inches', 'ScreenResolution', 'Cpu', 'Ram',
                                          'HDD', 'SSD', 'Flash_Storage', 'Memory', 'Gpu', 'OpSys', 'Weight',
                                          'Price_euros'})
product.index = list(range(len(product.index)))
product.insert(loc=0, column='product_id', value=list(range(len(product.index))))

# Extract company_have_product table
product_company = product[['Company', 'product_id']]
product_company_ids = []
for i in product_company.values:
    product_company_ids.append(company_set[i[0]])
product_company.insert(loc=0, column='company_id', value=product_company_ids)
product_company = product_company.drop("Company", axis=1)
product = product.drop("Company", axis=1)
product = product.drop("Product", axis=1)

# %% [markdown]
# Insert csv to table

# %%
# Insert to Table company
company.to_sql("company", Connection, index=False, if_exists='append')
# Insert to Table product
product.to_sql("product", Connection, index=False, if_exists='append')
# Insert to Table company
product_company.to_sql("company_have_product", Connection, index=False, if_exists='append')
# Out:
# 275

# %% [markdown]
#  QUESTION 3 (5 points)
#  ------------------------------------------
#
# 	To create data logic abstraction, create 3 views in the database such that
# 	your answers can use any number of select statements
# 	but can keep those statements as simple as selecting from a view (select * from <your view name>)

# %%
create_view_for_company = """
    Create view company_view as SELECT company_id, company_name from company;
"""
Connection.execute(create_view_for_company)

# %%
create_view_for_product = """
    Create view product_view as SELECT product_id, "Product_name", "Product_model", "HDD" , "SSD", "Flash_Storage" from product;
"""
Connection.execute(create_view_for_product)

# %%
create_view_for_company_have_product = """
    Create view company_have_product_view as SELECT * from company_have_product;
"""
Connection.execute(create_view_for_company_have_product)

# %% [markdown]
# test out put

# %%
select_view_company = """
    SELECT * from company_view;
"""
result = Connection.execute(select_view_company)
for i in result:
    print(i)
# Out:
# (0, 'Apple')
# (1, 'HP')
# (2, 'Acer')
# (3, 'Asus')
# (4, 'Dell')
# (5, 'Lenovo')
# (6, 'Chuwi')
# (7, 'MSI')
# (8, 'Microsoft')
# (9, 'Toshiba')
# (10, 'Huawei')
# (11, 'Xiaomi')
# (12, 'Vero')
# (13, 'Razer')
# (14, 'Mediacom')
# (15, 'Samsung')
# (16, 'Google')
# (17, 'Fujitsu')
# (18, 'LG')

# %%
select_view_product = """
    SELECT * from product_view;
"""
result = Connection.execute(select_view_product)
for i in result:
    print(i)
# Out:
# (0, 'MacBook', 'Pro', '0', '128GB', '0')
# (1, 'Macbook', 'Air', '0', '0', '128GB')
# (2, '250', 'G6', '0', '256GB', '0')
# (3, 'MacBook', 'Pro', '0', '512GB', '0')
# (4, 'MacBook', 'Pro', '0', '256GB', '0')
# (5, 'Aspire', '3', '500GB', '0', '0')
# (6, 'MacBook', 'Pro', '0', '0', '256GB')
# (7, 'Macbook', 'Air', '0', '0', '256GB')
# (8, 'ZenBook', 'UX430UN', '0', '512GB', '0')
# (9, 'Swift', '3', '0', '256GB', '0')
# (10, '250', 'G6', '500GB', '0', '0')
# (11, '250', 'G6', '500GB', '0', '0')
# (12, 'MacBook', 'Pro', '0', '256GB', '0')
# (13, 'Inspiron', '3567', '0', '256GB', '0')
# (14, 'MacBook', '12"', '0', '256GB', '0')
# (15, 'MacBook', 'Pro', '0', '256GB', '0')
# (16, 'Inspiron', '3567', '0', '256GB', '0')
# (17, 'MacBook', 'Pro', '0', '512GB', '0')
# (18, 'IdeaPad', '320-15IKB', '1TB', '0', '0')
# (19, 'XPS', '13', '0', '128GB', '0')
# (20, 'Vivobook', 'E200HA', '0', '0', '32GB')
# (21, 'Legion', 'Y520-15IKBN', '1TB', '128GB', '0')
# (22, '255', 'G6', '500GB', '0', '0')
# (23, 'Inspiron', '5379', '0', '256GB', '0')
# (24, '15-BS101nv', '(i7-8550U/8GB/256GB/FHD/W10)', '0', '256GB', '0')
# (25, 'Inspiron', '3567', '1TB', '0', '0')
# (26, 'MacBook', 'Air', '0', '0', '128GB')
# (27, 'Inspiron', '5570', '0', '256GB', '0')
# (28, 'Latitude', '5590', '0', '256GB', '0')
# (29, 'ProBook', '470', '1TB', '0', '0')
# (30, 'LapBook', '15.6"', '0', '0', '64GB')
# (31, 'E402WA-GA010T', '(E2-6110/2GB/32GB/W10)', '0', '0', '32GB')
# (32, '17-ak001nv', '(A6-9220/4GB/500GB/Radeon', '500GB', '0', '0')
# (33, 'XPS', '13', '0', '512GB', '0')
# (34, 'MacBook', 'Air', '0', '0', '256GB')
# (35, 'IdeaPad', '120S-14IAP', '0', '0', '64GB')
# (36, 'Aspire', '3', '1TB', '0', '0')
# (37, 'Inspiron', '5770', '1TB', '128GB', '0')
# (38, '250', 'G6', '1TB', '0', '0')
# (39, 'ProBook', '450', '0', '256GB', '0')
# (40, 'X540UA-DM186', '(i3-6006U/4GB/1TB/FHD/Linux)', '1TB', '0', '0')
# (41, 'Inspiron', '7577', '1TB', '256GB', '0')
# (42, 'X542UQ-GO005', '(i5-7200U/8GB/1TB/GeForce', '1TB', '0', '0')
# (43, 'Aspire', 'A515-51G', '0', '256GB', '0')
# (44, 'Inspiron', '7773', '1TB', '0', '0')
# (45, 'MacBook', 'Pro', '0', '256GB', '0')
# (46, 'IdeaPad', '320-15ISK', '0', '128GB', '0')
# (47, 'Rog', 'Strix', '1TB', '256GB', '0')
# (48, 'Inspiron', '3567', '0', '256GB', '0')
# (49, 'X751NV-TY001T', '(N4200/4GB/1TB/GeForce', '1TB', '0', '0')
# (50, 'Yoga', 'Book', '0', '0', '64GB')
# (51, 'Aspire', 'A515-51G', '0', '256GB', '0')
# (52, '255', 'G6', '0', '256GB', '0')
# (53, 'ProBook', '430', '0', '512GB', '0')
# (54, 'Aspire', '3', '1TB', '0', '0')
# (55, 'Inspiron', '3576', '0', '256GB', '0')
# (56, '15-bs002nv', '(i3-6006U/4GB/128GB/FHD/W10)', '0', '128GB', '0')
# (57, 'VivoBook', 'Max', '0', '256GB', '0')
# (58, 'GS73VR', '7RG', '2TB', '256GB', '0')
# (59, 'X541UA-DM1897', '(i3-6006U/4GB/256GB/FHD/Linux)', '0', '256GB', '0')
# (60, 'Inspiron', '5770', '2TB', '256GB', '0')
# (61, 'Vostro', '5471', '0', '256GB', '0')
# (62, 'IdeaPad', '520S-14IKB', '0', '256GB', '0')
# (63, 'UX410UA-GV350T', '(i5-8250U/8GB/256GB/FHD/W10)', '0', '256GB', '0')
# (64, '250', 'G6', '0', '256GB', '0')
# (65, 'ZenBook', 'Pro', '0', '512GB', '0')
# (66, '250', 'G6', '500GB', '0', '0')
# (67, 'Stream', '14-AX040wm', '0', '32GB', '0')
# (68, 'V310-15ISK', '(i5-7200U/4GB/1TB/FHD/W10)', '1TB', '0', '0')
# (69, 'FX753VE-GC093', '(i7-7700HQ/12GB/1TB/GeForce', '1TB', '0', '0')
# (70, 'Surface', 'Laptop', '0', '128GB', '0')
# (71, 'Inspiron', '5370', '0', '256GB', '0')
# (72, 'Inspiron', '5570', '0', '256GB', '0')
# (73, 'GL72M', '7RDX', '1TB', '128GB', '0')
# (74, 'Aspire', 'E5-475', '1TB', '0', '0')
# (75, 'FX503VD-E4022T', '(i7-7700HQ/8GB/1TB/GeForce', '1TB', '0', '0')
# (76, 'IdeaPad', '320-15IKBN', '2TB', '0', '0')
# (77, 'Inspiron', '5570', '1TB', '128GB', '0')
# (78, 'Aspire', 'A515-51G-32MX', '1TB', '0', '0')
# (79, 'ProBook', '470', '1TB', '128GB', '0')
# (80, 'Latitude', '5590', '0', '256GB', '0')
# (81, 'MacBook', '12"', '0', '512GB', '0')
# (82, 'ProBook', '440', '0', '256GB', '0')
# (83, 'IdeaPad', '320-15AST', '0', '128GB', '0')
# (84, 'Aspire', '3', '1TB', '0', '0')
# (85, 'Inspiron', '7577', '1TB', '128GB', '0')
# (86, 'Pavilion', '15-CK000nv', '0', '256GB', '0')
# (87, '250', 'G6', '0', '256GB', '0')
# (88, 'FX503VM-E4007T', '(i7-7700HQ/16GB/1TB', '1TB', '128GB', '0')
# (89, 'XPS', '13', '0', '256GB', '0')
# (90, 'FX550IK-DM018T', '(FX-9830P/8GB/1TB/Radeon', '1TB', '0', '0')
# (91, 'Aspire', '5', '1TB', '0', '0')
# (92, 'Probook', '430', '0', '512GB', '0')
# (93, 'Inspiron', '7577', '0', '256GB', '0')
# (94, 'Zenbook', 'UX430UA', '0', '256GB', '0')
# (95, 'Spin', '5', '0', '256GB', '0')
# (96, 'Inspiron', '3567', '1TB', '0', '0')
# (97, 'Inspiron', '3567', '0', '256GB', '0')
# (98, 'X541UV-DM1439T', '(i3-7100U/6GB/256GB/GeForce', '0', '256GB', '0')
# (99, 'Omen', '15-ce007nv', '1TB', '128GB', '0')
# (100, '15-bs017nv', '(i7-7500U/8GB/256GB/Radeon', '0', '256GB', '0')
# (101, '15-bw000nv', '(E2-9000e/4GB/500GB/Radeon', '500GB', '0', '0')
# (102, 'Inspiron', '3576', '1TB', '0', '0')
# (103, 'Envy', '13-ad009n', '0', '256GB', '0')
# (104, 'Surface', 'Laptop', '0', '256GB', '0')
# (105, 'Pavilion', '14-BK001nv', '0', '256GB', '0')
# (106, 'Ideapad', '310-15ISK', '1TB', '0', '0')
# (107, 'UX430UQ-GV209R', '(i7-7500U/8GB/256GB/GeForce', '0', '256GB', '0')
# (108, 'GP62M', '7REX', '1TB', '256GB', '0')
# (109, 'Thinkpad', 'T470', '0', '256GB', '0')
# (110, 'VivoBook', 'S15', '1TB', '256GB', '0')
# (111, 'XPS', '13', '0', '256GB', '0')
# (112, 'ThinkPad', 'Yoga', '0', '256GB', '0')
# (113, 'Probook', '440', '500GB', '0', '0')
# (114, 'XPS', '13', '0', '256GB', '0')
# (115, 'Spectre', 'x360', '0', '256GB', '0')
# (116, 'Probook', '440', '0', '512GB', '0')
# (117, 'Inspiron', '7570', '1TB', '256GB', '0')
# (118, 'X705UV-BX074T', '(i3-6006U/4GB/1TB/GeForce', '1TB', '0', '0')
# (119, 'VivoBook', 'S15', '0', '256GB', '0')
# (120, 'Spin', '3', '1TB', '0', '0')
# (121, 'GS63VR', '7RG', '2TB', '256GB', '0')
# (122, 'IdeaPad', '320-15IKBN', '0', '256GB', '0')
# (123, 'Probook', '470', '0', '512GB', '0')
# (124, 'Aspire', '3', '0', '256GB', '0')
# (125, '250', 'G6', '500GB', '0', '0')
# (126, 'Probook', '440', '1TB', '0', '0')
# (127, 'E402WA-GA007T', '(E2-6110/4GB/64GB/W10', '0', '64GB', '0')
# (128, 'Inspiron', '5770', '2TB', '256GB', '0')
# (129, 'ProBook', '470', '0', '256GB', '0')
# (130, 'Inspiron', '5567', '1TB', '0', '0')
# (131, 'Inspiron', '3567', '1TB', '0', '0')
# (132, 'Swift', '3', '0', '256GB', '0')
# (133, 'Aspire', 'A515-51G-37JS', '0', '256GB', '0')
# (134, '15-BS078nr', '(i7-7500U/8GB/1TB/W10)', '1TB', '0', '0')
# (135, 'Probook', '440', '0', '256GB', '0')
# (136, 'V110-15IAP', '(N3350/4GB/1TB/No', '1TB', '0', '0')
# (137, 'FX753VD-GC086T', '(i5-7300HQ/8GB/1TB', '1TB', '128GB', '0')
# (138, 'IdeaPad', '320-15IKBN', '1TB', '0', '0')
# (139, 'Envy', '13-AD007nv', '0', '256GB', '0')
# (140, 'Aspire', '5', '1TB', '0', '0')
# (141, 'ThinkPad', 'E480', '0', '256GB', '0')
# (142, 'Legion', 'Y520-15IKBN', '0', '256GB', '0')
# (143, 'Satellite', 'Pro', '500GB', '0', '0')
# (144, '255', 'G6', '0', '256GB', '0')
# (145, 'ZenBook', 'UX430UA', '0', '256GB', '0')
# (146, 'EliteBook', 'Folio', '0', '512GB', '0')
# (147, 'X541NA', '(N3350/4GB/1TB/FHD/W10)', '1TB', '0', '0')
# (148, 'GE72MVR', '7RG', '1TB', '256GB', '0')
# (149, 'Aspire', 'A315-51', '1TB', '0', '0')
# (150, 'Inspiron', '5577', '0', '512GB', '0')
# (151, 'Inspiron', '7567', '0', '0', '0')
# (152, 'V110-15IKB', '(i5-7200U/4GB/128GB/W10)', '0', '128GB', '0')
# (153, 'GE73VR', '7RE', '1TB', '256GB', '0')
# (154, 'EliteBook', '840', '0', '256GB', '0')
# (155, '15-BS103nv', '(i5-8250U/6GB/256GB/Radeon', '0', '256GB', '0')
# (156, 'Yoga', '520-14IKB', '0', '256GB', '0')
# (157, 'ZenBook', 'Flip', '0', '256GB', '0')
# (158, 'Inspiron', '5579', '0', '256GB', '0')
# (159, 'Satellite', 'Pro', '500GB', '0', '0')
# (160, 'X555BP-XX180T', '(A9-9420/4GB/1TB/Radeon', '1TB', '0', '0')
# (161, 'Aspire', 'A517-51G', '0', '256GB', '0')
# (162, 'Inspiron', '3576', '0', '256GB', '0')
# (163, 'Legion', 'Y520-15IKBN', '0', '256GB', '0')
# (164, 'Aspire', 'A315-31', '1TB', '0', '0')
# (165, 'GE63VR', '7RE', '1TB', '256GB', '0')
# (166, 'Aspire', '3', '1TB', '0', '0')
# (167, 'Inspiron', '5577', '1TB', '128GB', '0')
# (168, 'Aspire', 'A517-51G', '0', '256GB', '0')
# (169, 'ProBook', '430', '500GB', '0', '0')
# (170, 'MateBook', 'X', '0', '256GB', '0')
# (171, '17-bs001nv', '(i5-7200U/6GB/2TB/Radeon', '2TB', '0', '0')
# (172, 'IdeaPad', '320-15AST', '500GB', '0', '0')
# (173, 'Satellite', 'Pro', '500GB', '0', '0')
# (174, 'ProBook', '470', '0', '256GB', '0')
# (175, 'Inspiron', '3567', '1TB', '0', '0')
# (176, 'Aspire', 'A315-51', '0', '128GB', '0')
# (177, 'GT80S', '6QF-074US', '1TB', '512GB', '0')
# (178, 'V310-15IKB', '(i5-7200U/8GB/1TB', '1TB', '128GB', '0')
# (179, 'Spectre', 'x360', '0', '256GB', '0')
# (180, 'Inspiron', '5570', '2TB', '256GB', '0')
# (181, 'XPS', '13', '0', '256GB', '0')
# (182, 'Yoga', '920-13IKB', '0', '512GB', '0')
# (183, 'Satellite', 'Pro', '0', '128GB', '0')
# (184, 'Mi', 'Notebook', '0', '256GB', '0')
# (185, 'Inspiron', '7773', '0', '512GB', '0')
# (186, 'XPS', '15', '0', '512GB', '0')
# (187, 'Legion', 'Y520-15IKBN', '0', '256GB', '0')
# (188, 'Swift', '7', '0', '256GB', '0')
# (189, 'Inspiron', '5770', '1TB', '128GB', '0')
# (190, 'Thinkpad', 'Yoga', '0', '1TB', '0')
# (191, 'K147', '(N3350/4GB/32GB/FHD/W10)', '0', '0', '32GB')
# (192, 'Mi', 'Notebook', '0', '256GB', '0')
# (193, 'IdeaPad', '320-17IKBR', '0', '256GB', '0')
# (194, 'Inspiron', '5379', '1TB', '0', '0')
# (195, 'ProBook', '470', '1TB', '0', '0')
# (196, 'Blade', 'Pro', '0', '1TB', '0')
# (197, 'ProBook', '430', '0', '512GB', '0')
# (198, 'Omen', '17-W295', '1TB', '256GB', '0')
# (199, 'Probook', '470', '0', '256GB', '0')
# (200, 'Inspiron', '7577', '1TB', '512GB', '0')
# (201, 'V110-15ISK', '(i5-6200U/4GB/128GB/W10)', '0', '128GB', '0')
# (202, 'Aspire', 'E5-576G', '1TB', '0', '0')
# (203, 'Legion', 'Y720-15IKB', '1TB', '512GB', '0')
# (204, 'Precision', '7520', '1TB', '256GB', '0')
# (205, 'Legion', 'Y520-15IKBN', '0', '512GB', '0')
# (206, 'Inspiron', '3567', '1TB', '0', '0')
# (207, 'XPS', '13', '0', '256GB', '0')
# (208, 'XPS', '13', '0', '256GB', '0')
# (209, 'IdeaPad', '320-15IKBN', '0', '256GB', '0')
# (210, 'Aspire', '7', '1TB', '0', '0')
# (211, 'ROG', 'GL703VD-GC028T', '1TB', '256GB', '0')
# (212, '15-bs018nq', '(i3-6006U/4GB/500GB/FHD/No', '500GB', '0', '0')
# (213, 'IdeaPad', '320-15IKBN', '0', '256GB', '0')
# (214, 'MateBook', 'X', '0', '512GB', '0')
# (215, 'Inspiron', '5370', '0', '256GB', '0')
# (216, 'IdeaPad', '320-17IKB', '1TB', '0', '0')
# (217, 'Probook', '440', '0', '256GB', '0')
# (218, 'Latitude', '5490', '0', '256GB', '0')
# (219, 'Inspiron', '5379', '0', '512GB', '0')
# (220, 'Inspiron', '3576', '0', '256GB', '0')
# (221, 'Yoga', '520-14IKB', '0', '256GB', '0')
# (222, 'Portege', 'Z30-C-16L', '0', '256GB', '0')
# (223, 'ProBook', '450', '1TB', '0', '0')
# (224, 'Alienware', '17', '1TB', '256GB', '0')
# (225, 'Aspire', 'E5-576G', '0', '256GB', '0')
# (226, 'Inspiron', '5567', '1TB', '0', '0')
# (227, 'Vivobook', 'X541UV-DM1217T', '0', '256GB', '0')
# (228, 'K756UX-T4340T', '(i5-7200U/8GB/500GB', '500GB', '256GB', '0')
# (229, 'ZBook', '15u', '1TB', '0', '0')
# (230, 'Pro', 'P2540UA-XO0198T', '1TB', '0', '0')
# (231, '15-rb013nv', '(E2-9000e/4GB/500GB/W10)', '500GB', '0', '0')
# (232, 'Legion', 'Y720-15IKB', '1TB', '256GB', '0')
# (233, 'Vostro', '5468', '0', '256GB', '0')
# (234, 'Aspire', 'R7', '0', '256GB', '0')
# (235, 'Inspiron', '5567', '0', '256GB', '0')
# (236, 'Aspire', 'A315-51', '1TB', '0', '0')
# (237, 'X555QG-DM242T', '(A10-9620P/4GB/1TB', '1TB', '128GB', '0')
# (238, 'ROG', 'G703VI-E5062T', '1TB', '512GB', '0')
# (239, 'Nitro', 'AN515-51', '0', '256GB', '0')
# (240, 'IdeaPad', '320-15ISK', '0', '128GB', '0')
# (241, 'VivoBook', 'Pro', '1TB', '128GB', '0')
# (242, 'F756UX-T4201D', '(i7-7500U/8GB/128GB', '1TB', '128GB', '0')
# (243, 'Inspiron', '5577', '0', '256GB', '0')
# (244, 'Yoga', '910-13IKB', '0', '256GB', '0')
# (245, 'Inspiron', '5570', '2TB', '128GB', '0')
# (246, '15-bs015dx', '(i5-7200U/8GB/1TB/W10)', '1TB', '0', '0')
# (247, 'Rog', 'G701VIK-BA060T', '0', '256GB', '0')
# (248, 'ProBook', '430', '500GB', '0', '0')
# (249, 'MacBook', 'Pro', '0', '512GB', '0')
# (416, 'Latitude', '3380', '0', '128GB', '0')
# (250, 'Inspiron', '5579', '1TB', '0', '0')
# (251, 'ROG', 'G752VSK-GC493T', '1TB', '256GB', '0')
# (252, 'X505BP-BR019T', '(A9-9420/4GB/1TB/Radeon', '1TB', '0', '0')
# (253, 'Yoga', '920-13IKB', '0', '512GB', '0')
# (254, 'Aspire', '5', '0', '256GB', '0')
# (255, 'Vostro', '5370', '0', '256GB', '0')
# (256, '15-BW094nd', '(A6-9220/8GB/128GB/W10)', '0', '128GB', '0')
# (257, 'Envy', '17-U275cl', '1TB', '0', '0')
# (258, 'GT73EVR', '7RE', '1TB', '512GB', '0')
# (259, 'Yoga', '720-15IKB', '0', '512GB', '0')
# (260, 'Inspiron', '5770', '1TB', '128GB', '0')
# (261, 'IdeaPad', '320-15ISK', '0', '256GB', '0')
# (262, 'ProBook', '450', '500GB', '0', '0')
# (263, 'Vostro', '3568', '1TB', '0', '0')
# (264, 'Inspiron', '3567', '1TB', '0', '0')
# (265, 'Inspiron', '5579', '0', '256GB', '0')
# (266, 'ZenBook', 'Flip', '0', '512GB', '0')
# (267, 'IdeaPad', '320-15IKBN', '1TB', '0', '0')
# (268, 'Probook', '470', '1TB', '0', '0')
# (269, 'V330-15IKB', '(i7-8550U/8GB/256GB/FHD/W10)', '0', '256GB', '0')
# (270, 'MacBook', 'Pro', '0', '512GB', '0')
# (271, 'Rog', 'Strix', '1TB', '256GB', '0')
# (272, 'Inspiron', '3576', '0', '256GB', '0')
# (273, 'ThinkPad', 'X1', '0', '512GB', '0')
# (274, 'Satellite', 'Pro', '500GB', '0', '0')
# (275, 'Inspiron', '5567', '1TB', '0', '0')
# (276, 'Inspiron', '5770', '1TB', '128GB', '0')
# (277, 'Aspire', 'A515-51G', '1TB', '0', '0')
# (278, 'IdeaPad', '320-17ISK', '1TB', '0', '0')
# (279, 'IdeaPad', '320-17IKBR', '2TB', '0', '0')
# (280, 'IdeaPad', '320-17IKB', '1TB', '128GB', '0')
# (281, 'Inspiron', '3567', '1TB', '0', '0')
# (282, 'Legion', 'Y520-15IKBN', '0', '256GB', '0')
# (283, 'Ideapad', '320-15IKBN', '0', '256GB', '0')
# (284, 'Aspire', 'A517-51G', '0', '256GB', '0')
# (285, 'SP315-51', '(i7-7500U/12GB/1TB/FHD/W10)', '1TB', '0', '0')
# (286, 'Thinkpad', 'T570', '0', '256GB', '0')
# (287, 'VivoBook', 'S15', '0', '256GB', '0')
# (288, 'Legion', 'Y520-15IKBN', '1TB', '256GB', '0')
# (289, 'IdeaPad', '320-15IKB', '1TB', '0', '0')
# (290, 'Chromebook', 'C910-C2ST', '0', '16GB', '0')
# (291, 'FX753VD-GC071T', '(i7-7700HQ/8GB/1TB/GeForce', '1TB', '0', '0')
# (292, '17-BS037cl', '(i3-6006U/8GB/1TB/W10)', '1TB', '0', '0')
# (293, 'XPS', '15', '0', '256GB', '0')
# (294, 'V330-15IKB', '(i5-8250U/8GB/256GB/FHD/W10)', '0', '256GB', '0')
# (295, 'Legion', 'Y720-15IKB', '1TB', '0', '0')
# (296, 'Aspire', 'A715-71G', '0', '256GB', '0')
# (297, 'Precision', '7720', '0', '256GB', '0')
# (298, 'IdeaPad', '310-15ABR', '1TB', '0', '0')
# (299, 'ZenBook', 'UX530UQ-PRO', '0', '512GB', '0')
# (300, 'VivoBook', 'S14', '0', '128GB', '0')
# (301, 'Rog', 'GL702VS-GC095T', '1TB', '256GB', '0')
# (302, 'IdeaPad', '320-17IKB', '1TB', '0', '0')
# (303, 'IdeaPad', '320-15IKBN', '2TB', '0', '0')
# (304, 'GL553VE-FY082T', '(i7-7700HQ/8GB/1TB', '1TB', '128GB', '0')
# (305, 'IdeaPad', '320-15IAP', '1TB', '0', '0')
# (306, 'EliteBook', 'x360', '0', '256GB', '0')
# (307, 'Satellite', 'Pro', '0', '256GB', '0')
# (308, 'IdeaPad', '320-15IKB', '1TB', '128GB', '0')
# (309, '250', 'G6', '1TB', '0', '0')
# (310, 'IdeaPad', '720S-13IKB', '0', '256GB', '0')
# (311, 'XPS', '13', '0', '1TB', '0')
# (312, 'GE63VR', '7RF', '1TB', '256GB', '0')
# (313, 'ES1-523-84K7', '(A8-7410/8GB/256GB/FHD/W10)', '0', '256GB', '0')
# (314, 'VivoBook', 'Flip', '0', '0', '32GB')
# (315, 'Inspiron', '5570', '1TB', '128GB', '0')
# (316, 'Spectre', 'x360', '0', '1TB', '0')
# (317, 'ThinkPad', '13', '0', '0', '16GB')
# (318, 'ProBook', '640', '0', '256GB', '0')
# (319, 'TravelMate', 'B', '0', '0', '128GB')
# (320, 'Elitebook', '840', '0', '256GB', '0')
# (321, 'IdeaPad', '320-17IKB', '1TB', '0', '0')
# (322, 'ZenBook', 'UX410UA-GV183T', '0', '256GB', '0')
# (323, 'ProBook', '450', '1TB', '0', '0')
# (324, 'Aspire', '5', '0', '256GB', '0')
# (325, 'IdeaPad', '120S-14IAP', '0', '0', '32GB')
# (326, 'Aspire', 'E5-575', '1TB', '0', '0')
# (327, 'VivoBook', 'S15', '0', '256GB', '0')
# (328, 'Elitebook', '820', '0', '256GB', '0')
# (329, 'XPS', '15', '0', '1TB', '0')
# (330, 'GL72M', '7REX', '1TB', '256GB', '0')
# (331, 'Satellite', 'Pro', '0', '256GB', '0')
# (332, 'UX510UX-CN269T', '(i7-7500U/8GB/256GB', '1TB', '256GB', '0')
# (333, 'V310-15ISK', '(i3-6006U/4GB/1TB/FHD/W10)', '1TB', '0', '0')
# (334, 'FX553VD-FY647T', '(i7-7700HQ/8GB/256GB/GeForce', '0', '256GB', '0')
# (335, 'EliteBook', '840', '0', '256GB', '0')
# (336, 'Inspiron', '7570', '1TB', '128GB', '0')
# (337, 'Elitebook', '850', '0', '256GB', '0')
# (338, 'X541NA', '(N3350/4GB/1TB/Linux)', '1TB', '0', '0')
# (339, 'Inspiron', '7570', '0', '256GB', '0')
# (340, 'Inspiron', '3552', '500GB', '0', '0')
# (341, 'IdeaPad', '320-15ABR', '2TB', '0', '0')
# (342, 'ProBook', '450', '1TB', '0', '0')
# (343, 'Yoga', '920-13IKB', '0', '512GB', '0')
# (344, 'XPS', '13', '0', '256GB', '0')
# (345, 'Legion', 'Y520-15IKBN', '2TB', '256GB', '0')
# (346, 'Stream', '14-AX001nv', '0', '0', '32GB')
# (347, 'Latitude', '5590', '0', '256GB', '0')
# (348, 'VivoBook', 'Flip', '0', '0', '32GB')
# (349, 'Inspiron', '5570', '1TB', '0', '0')
# (350, 'XPS', '15', '0', '512GB', '0')
# (351, 'Elitebook', '850', '0', '256GB', '0')
# (352, 'GP72MVR', '7RFX', '1TB', '128GB', '0')
# (353, 'Zbook', '15', '0', '256GB', '0')
# (354, 'Tecra', 'A50-C-21G', '0', '512GB', '0')
# (355, 'Inspiron', '5570', '2TB', '128GB', '0')
# (356, 'IdeaPad', '320-15IAP', '1TB', '0', '0')
# (357, 'Inspiron', '7577', '1TB', '0', '0')
# (358, 'Inspiron', '3567', '2TB', '0', '0')
# (359, 'Latitude', '7480', '0', '256GB', '0')
# (360, '250', 'G6', '500GB', '0', '0')
# (361, 'Zenbook', 'UX410UA-GV027T', '0', '256GB', '0')
# (362, 'IdeaPad', '320-17IKB', '1TB', '128GB', '0')
# (363, '250', 'G6', '1TB', '0', '0')
# (364, 'IdeaPad', '320-15ISK', '0', '256GB', '0')
# (365, '15-AY023na', '(N3710/8GB/2TB/W10)', '2TB', '0', '0')
# (366, 'Inspiron', '5770', '1TB', '128GB', '0')
# (367, 'Legion', 'Y520-15IKBN', '1TB', '128GB', '0')
# (368, 'Inspiron', '5567', '0', '256GB', '0')
# (369, 'Elitebook', '1040', '0', '256GB', '0')
# (370, 'ZenBook', 'Flip', '2TB', '512GB', '0')
# (371, 'Aspire', '3', '0', '128GB', '0')
# (372, 'Rog', 'Strix', '1TB', '256GB', '0')
# (373, 'IdeaPad', '110-17ACL', '0', '128GB', '0')
# (374, 'Inspiron', '5379', '0', '256GB', '0')
# (375, '15-bw003nv', '(A9-Series-9420/4GB/256GB/FHD/W10)', '0', '256GB', '0')
# (376, 'Yoga', '11e', '0', '128GB', '0')
# (377, 'Inspiron', '3552', '500GB', '0', '0')
# (378, 'VivoBook', 'E403NA', '0', '0', '32GB')
# (379, 'Aspire', '7', '1TB', '0', '0')
# (380, 'Omen', '17-w212nv', '1TB', '128GB', '0')
# (381, 'V310-15ISK', '(i3-6006U/4GB/128GB/FHD/No', '0', '128GB', '0')
# (382, 'ROG', 'Strix', '1TB', '128GB', '0')
# (383, 'IdeaPad', '720S-14IKB', '0', '256GB', '0')
# (384, 'Zenbook', 'Flip', '0', '512GB', '0')
# (385, 'Thinkpad', 'X1', '0', '512GB', '0')
# (386, 'Ideapad', '510S-13IKB', '0', '128GB', '0')
# (387, 'Precision', '3510', '500GB', '0', '0')
# (388, 'Precision', '5520', '0', '256GB', '0')
# (389, 'ThinkPad', 'X1', '0', '512GB', '0')
# (390, 'Rog', 'GL753VD-GC042T', '1TB', '0', '0')
# (391, 'Rog', 'GL753VE-GC070T', '1TB', '256GB', '0')
# (392, 'Aspire', '5', '1TB', '0', '0')
# (393, 'Leopard', 'GP72M', '0', '256GB', '0')
# (394, 'Inspiron', '5567', '0', '256GB', '0')
# (395, '15-BW004nv', '(A9-9420/4GB/256GB/Radeon', '0', '256GB', '0')
# (396, 'ThinkPad', 'E580', '0', '256GB', '0')
# (397, 'ThinkPad', 'L470', '0', '256GB', '0')
# (398, 'Precision', 'M5520', '0', '256GB', '0')
# (399, 'Thinkpad', 'X1', '0', '1TB', '0')
# (400, 'IdeaPad', '320-15IAP', '1TB', '0', '0')
# (401, 'FX753VD-GC461T', '(i7-7700HQ/16GB/1TB', '1TB', '256GB', '0')
# (402, 'ThinkPad', 'E580', '1TB', '256GB', '0')
# (403, 'Aspire', '7', '0', '256GB', '0')
# (404, 'GE73VR', '7RF', '1TB', '256GB', '0')
# (405, 'Zenbook', '3', '0', '512GB', '0')
# (406, 'Portege', 'Z30-C-16P', '0', '512GB', '0')
# (407, 'Latitude', '7480', '0', '512GB', '0')
# (408, 'IdeaPad', '320-15ISK', '500GB', '0', '0')
# (409, 'Lenovo', 'IdeaPad', '0', '0', '32GB')
# (410, 'ThinkPad', 'P51', '0', '512GB', '0')
# (411, 'Thinkpad', 'T470p', '0', '512GB', '0')
# (412, '15-BS028nv', '(i3-6006U/4GB/1TB/Radeon', '1TB', '0', '0')
# (413, 'Aspire', 'R7', '0', '256GB', '0')
# (414, 'ZenBook', 'Flip', '0', '256GB', '0')
# (415, 'Inspiron', '3567', '0', '256GB', '0')
# (417, 'EliteBook', '1040', '0', '256GB', '0')
# (418, 'Inspiron', '3567', '1TB', '0', '0')
# (419, 'ThinkPad', 'E480', '0', '256GB', '0')
# (420, 'Yoga', '720-15IKB', '0', '512GB', '0')
# (421, 'LapBook', '12.3', '0', '0', '64GB')
# (422, 'ProBook', '650', '0', '256GB', '0')
# (423, 'X542UQ-DM117', '(i3-7100U/8GB/1TB/GeForce', '1TB', '0', '0')
# (424, 'Alienware', '17', '1TB', '256GB', '0')
# (425, 'Inspiron', '7577', '1TB', '128GB', '0')
# (426, 'Inspiron', '5570', '2TB', '256GB', '0')
# (427, 'Latitude', '5480', '0', '256GB', '0')
# (428, 'Omen', '17-w207nv', '1TB', '256GB', '0')
# (429, 'FlexBook', 'Edge', '0', '32GB', '0')
# (430, 'Chromebook', '3', '0', '0', '16GB')
# (431, 'Thinkpad', '13', '0', '256GB', '0')
# (432, 'IdeaPad', '320s-14IKB', '0', '128GB', '0')
# (433, 'Thinkpad', 'T570', '0', '512GB', '0')
# (434, 'Thinkpad', 'P51', '0', '512GB', '0')
# (435, 'Rog', 'Strix', '1TB', '256GB', '0')
# (436, '15-ra044nv', '(N3060/4GB/500GB/W10)', '500GB', '0', '0')
# (437, 'Pixelbook', '(Core', '0', '512GB', '0')
# (438, 'ThinkPad', 'T470s', '0', '512GB', '0')
# (439, 'VivoBook', 'Max', '0', '256GB', '0')
# (440, 'IdeaPad', '320-15AST', '1TB', '0', '0')
# (441, 'Inspiron', '5570', '0', '256GB', '0')
# (442, 'ThinkPad', 'X270', '0', '256GB', '0')
# (443, 'IdeaPad', '320-15IAP', '0', '128GB', '0')
# (444, 'Omen', '15-AX205na', '1TB', '128GB', '0')
# (445, 'Latitude', '5480', '0', '256GB', '0')
# (446, 'Aspire', 'ES1-572', '500GB', '0', '0')
# (447, 'Precision', '3520', '1TB', '0', '64GB')
# (448, 'GV62', '7RD-1686NL', '0', '256GB', '0')
# (449, 'Surface', 'Laptop', '0', '512GB', '0')
# (450, '15-bs024nv', '(i5-7200U/8GB/128GB/W10)', '0', '128GB', '0')
# (451, 'Precision', '3520', '0', '256GB', '0')
# (452, 'ProBook', '650', '0', '512GB', '0')
# (453, 'ThinkPad', 'T470', '0', '256GB', '0')
# (454, 'Inspiron', '5570', '1TB', '128GB', '0')
# (455, 'Inspiron', '3168', '500GB', '0', '0')
# (456, 'Alienware', '17', '1TB', '0', '0')
# (457, 'Surface', 'Laptop', '0', '128GB', '0')
# (458, 'Surface', 'Laptop', '0', '256GB', '0')
# (459, '17-BS092ND', '(i3-6006U/8GB/256GB/W10)', '0', '256GB', '0')
# (460, 'Aspire', 'E5-576G', '1TB', '0', '0')
# (461, 'TravelMate', 'B', '0', '128GB', '0')
# (462, 'Pro', 'P2540UA-AB51', '1TB', '0', '0')
# (463, 'IdeaPad', '510s-14IKB', '0', '512GB', '0')
# (464, 'Thinkpad', 'P51', '0', '256GB', '0')
# (465, 'X541NA-PD1003Y', '(N4200/4GB/500GB/W10)', '500GB', '0', '0')
# (466, 'Aspire', '5', '500GB', '0', '0')
# (467, 'Inspiron', '5570', '2TB', '0', '0')
# (468, 'Omen', '17-an006nv', '1TB', '0', '0')
# (469, 'Thinkpad', 'T460s', '0', '256GB', '0')
# (470, 'Spectre', 'x360', '0', '512GB', '0')
# (471, 'ZBook', '15u', '500GB', '0', '0')
# (472, 'Pixelbook', '(Core', '0', '128GB', '0')
# (473, 'Latitude', '7390', '0', '256GB', '0')
# (474, 'ZenBook', 'Pro', '1TB', '128GB', '0')
# (475, 'Latitude', 'E5470', '0', '128GB', '0')
# (476, 'Precision', 'M5520', '0', '256GB', '0')
# (477, 'Thinkpad', 'T470', '0', '180GB', '0')
# (478, 'Inspiron', '3576', '1TB', '0', '0')
# (479, 'Portege', 'X30-D-10J', '0', '256GB', '0')
# (480, 'Inspiron', '7570', '0', '512GB', '0')
# (481, 'Vostro', '3568', '1TB', '0', '0')
# (482, 'ProBook', '430', '0', '128GB', '0')
# (483, 'Lapbook', '15,6', '0', '0', '64GB')
# (484, 'ThinkPad', 'E570', '0', '128GB', '0')
# (485, 'ThinkPad', 'E480', '0', '256GB', '0')
# (486, 'Precision', '3520', '0', '512GB', '0')
# (487, 'XPS', '15', '0', '512GB', '0')
# (488, 'Thinkpad', 'X270', '0', '512GB', '0')
# (489, 'Zenbook', 'UX390UA', '0', '512GB', '0')
# (490, 'Thinkpad', 'E570', '0', '256GB', '0')
# (491, 'Portege', 'X30-D-10L', '0', '512GB', '0')
# (492, 'VivoBook', 'Pro', '1TB', '128GB', '0')
# (493, 'Aspire', '5', '1TB', '0', '0')
# (494, 'Rog', 'G752VL-UH71T', '1TB', '256GB', '0')
# (495, 'Thinkpad', 'X260', '0', '180GB', '0')
# (496, 'Ideapad', '520-15IKBR', '0', '256GB', '0')
# (497, 'EliteBook', '840', '0', '1TB', '0')
# (498, 'ThinkPad', '13', '0', '256GB', '0')
# (499, 'ThinkPad', 'L570', '0', '256GB', '0')
# (500, 'VivoBook', 'E201NA', '0', '0', '64GB')
# (501, '15-BS026nv', '(i5-7200U/8GB/256GB/Radeon', '0', '256GB', '0')
# (502, 'Yoga', '920-13IKB', '0', '256GB', '0')
# (503, 'IdeaPad', '320-14IAP', '500GB', '0', '0')
# (504, 'Chromebook', 'N23', '0', '16GB', '0')
# (505, 'ThinkPad', '13', '0', '256GB', '0')
# (506, 'ZenBook', 'UX510UX-CN211T', '1TB', '256GB', '0')
# (507, 'Aspire', 'A515-51G-59QF', '1TB', '0', '0')
# (508, 'Envy', '13-AB002nv', '0', '512GB', '0')
# (509, 'Legion', 'Y520-15IKBN', '1TB', '256GB', '0')
# (510, 'XPS', '13', '0', '128GB', '0')
# (511, 'Aspire', 'A515-51G', '500GB', '0', '0')
# (512, 'Vostro', '5568', '1TB', '0', '0')
# (513, 'Inspiron', '5570', '2TB', '256GB', '0')
# (514, 'Mi', 'Notebook', '0', '256GB', '0')
# (515, 'VivoBook', 'E12', '0', '0', '32GB')
# (516, '15-bs190od', '(i5-8250U/4GB/1TB/W10)', '1TB', '0', '0')
# (517, 'ROG', 'Zephyrus', '0', '512GB', '0')
# (518, 'Probook', '450', '0', '256GB', '0')
# (519, 'FX753VE-GC155T', '(i7-7700HQ/16GB/1TB', '1TB', '256GB', '0')
# (520, 'Legion', 'Y720-15IKB', '1TB', '256GB', '0')
# (521, 'Spectre', 'X360', '0', '256GB', '0')
# (522, 'Latitude', '5480', '0', '256GB', '0')
# (523, 'ProBook', '440', '0', '128GB', '0')
# (524, 'Inspiron', '5770', '1TB', '128GB', '0')
# (525, 'ThinkPad', 'L470', '0', '256GB', '0')
# (526, 'IdeaPad', '320-15IKB', '1TB', '0', '0')
# (527, 'IdeaPad', '320-15ISK', '2TB', '0', '0')
# (528, 'Inspiron', '3567', '500GB', '0', '0')
# (529, 'Latitude', '5580', '0', '256GB', '0')
# (530, 'Alienware', '17', '1TB', '128GB', '0')
# (531, 'Satellite', 'Pro', '500GB', '0', '0')
# (532, 'Zenbook', 'UX510UW-FI095T', '1TB', '256GB', '0')
# (533, 'SmartBook', 'Edge', '0', '32GB', '0')
# (534, 'ROG', 'Strix', '1TB', '128GB', '0')
# (535, 'Latitude', '5580', '0', '256GB', '0')
# (536, 'Inspiron', '5570', '0', '256GB', '0')
# (537, '250', 'G6', '0', '256GB', '0')
# (538, 'Omen', '15-ce006nv', '1TB', '0', '0')
# (539, 'Thinkpad', 'E470', '0', '256GB', '0')
# (540, 'XPS', '13', '0', '256GB', '0')
# (541, 'Vostro', '5468', '0', '128GB', '0')
# (542, 'Envy', '13-AB020nr', '0', '256GB', '0')
# (543, 'Aspire', '7', '1TB', '0', '0')
# (544, 'VivoBook', 'X540YA-XX519T', '500GB', '0', '0')
# (545, 'ProBook', '450', '0', '128GB', '0')
# (546, 'ThinkPad', 'E470', '500GB', '0', '0')
# (547, 'V310-15ISK', '(i5-6200U/4GB/1TB/FHD/No', '1TB', '0', '0')
# (548, '250', 'G6', '500GB', '0', '0')
# (549, 'ThinkPad', 'T570', '0', '512GB', '0')
# (550, 'IdeaPad', '320-15ISK', '0', '128GB', '0')
# (551, 'Latitude', '5580', '0', '256GB', '0')
# (552, 'Alienware', '17', '1TB', '256GB', '0')
# (553, '17-X047na', '(i3-6006U/8GB/1TB/W10)', '1TB', '0', '0')
# (554, 'ProBook', '470', '1TB', '0', '0')
# (555, 'A541NA-GO342', '(N3350/4GB/500GB/Linux)', '500GB', '0', '0')
# (556, 'SmartBook', '130', '0', '0', '32GB')
# (557, 'IdeaPad', '320-17IKB', '1TB', '128GB', '0')
# (558, '15-bw007nv', '(A10-9620P/6GB/128GB/Radeon', '0', '128GB', '0')
# (559, 'Vostro', '3568', '1TB', '0', '0')
# (560, 'Spin', 'SP111-31', '0', '0', '32GB')
# (561, 'V330-15IKB', '(i3-7130U/4GB/128GB/FHD/W10)', '0', '128GB', '0')
# (562, 'EliteBook', '1030', '0', '512GB', '0')
# (563, 'Thinkpad', 'P71', '0', '256GB', '0')
# (564, 'FX553VD-DM627T', '(i5-7300HQ/8GB/1TB', '1TB', '128GB', '0')
# (565, 'XPS', '13', '0', '128GB', '0')
# (566, 'Latitude', '5580', '500GB', '0', '0')
# (567, 'Lifebook', 'A557', '1TB', '0', '0')
# (568, 'IdeaPad', '320-15IAP', '500GB', '0', '0')
# (569, 'ThinkPad', 'L470', '500GB', '0', '0')
# (570, 'ZBook', '17', '500GB', '0', '0')
# (571, '14-am079na', '(N3710/8GB/2TB/W10)', '2TB', '0', '0')
# (572, '15-cd005nv', '(A9-9420/6GB/256GB/Radeon', '0', '256GB', '0')
# (573, 'Thinkpad', 'E570', '0', '256GB', '0')
# (574, 'V330-15IKB', '(i5-8250U/4GB/500GB/FHD/W10)', '500GB', '0', '0')
# (575, 'SmartBook', '141', '0', '32GB', '0')
# (576, 'Tecra', 'X40-D-10H', '0', '512GB', '0')
# (577, 'IdeaPad', 'Y910-17ISK', '1TB', '256GB', '0')
# (578, 'GT73VR', 'Titan', '1TB', '512GB', '0')
# (579, 'Inspiron', '3567', '0', '256GB', '0')
# (580, 'SmartBook', 'Edge', '0', '32GB', '0')
# (581, 'Latitude', '5580', '500GB', '0', '0')
# (582, 'ProBook', '430', '0', '128GB', '0')
# (583, 'Latitude', '5580', '0', '256GB', '0')
# (584, 'Chromebook', '11', '0', '0', '16GB')
# (585, 'GT80S', '6QE', '1TB', '128GB', '0')
# (586, 'Omen', '17-AN010nv', '1TB', '256GB', '0')
# (587, 'Thinkpad', 'T460s', '0', '256GB', '0')
# (588, 'Ideapad', '320-15IKBR', '1TB', '0', '0')
# (589, 'ROG', 'Strix', '1TB', '128GB', '0')
# (590, 'TP501UA-CJ131T', '(i5-7200U/8GB/1TB/W10)', '1TB', '0', '0')
# (591, 'IdeaPad', '320-15ABR', '0', '512GB', '0')
# (592, 'Inspiron', '3179', '0', '128GB', '0')
# (593, 'Notebook', 'Odyssey', '1TB', '128GB', '0')
# (594, 'V320-17ISK', '(i3-6006U/4GB/500GB/FHD/No', '500GB', '0', '0')
# (595, 'IdeaPad', '110-15ISK', '1TB', '0', '0')
# (596, 'ThinkPad', 'Yoga', '0', '512GB', '0')
# (597, 'Thinkpad', 'T470p', '0', '256GB', '0')
# (598, 'Latitude', '5289', '0', '256GB', '0')
# (599, 'Precision', '3520', '0', '256GB', '0')
# (600, 'EliteBook', '850', '0', '256GB', '0')
# (601, 'ProBook', '450', '500GB', '0', '0')
# (602, 'Aspire', '1', '0', '0', '32GB')
# (603, 'Laptop', 'MSI', '1TB', '128GB', '0')
# (604, 'Vostro', '3568', '1TB', '0', '0')
# (605, 'GS63VR', '7RF', '2TB', '256GB', '0')
# (606, 'Tecra', 'Z50-C-144', '0', '256GB', '0')
# (607, 'IdeaPad', '310-15IKB', '1TB', '0', '0')
# (608, 'Yoga', '720-15IKB', '0', '256GB', '0')
# (609, 'Swift', 'SF114-31-P5HY', '0', '0', '128GB')
# (610, 'Thinkpad', 'P51', '0', '1TB', '0')
# (611, 'Inspiron', '7559', '1TB', '0', '0')
# (612, 'Vostro', '3568', '1TB', '0', '0')
# (613, 'Inspiron', '3567', '1TB', '0', '0')
# (614, 'Latitude', '5580', '500GB', '0', '0')
# (615, 'FX753VD-GC007T', '(i7-7700HQ/8GB/1TB', '1TB', '128GB', '0')
# (616, 'Vostro', '3568', '0', '128GB', '0')
# (617, 'EliteBook', '850', '0', '512GB', '0')
# (618, 'GT62VR', '7RE', '1TB', '256GB', '0')
# (619, 'CB5-132T-C9KK', '(N3160/4GB/32GB/Chrome', '0', '0', '32GB')
# (620, 'ProBook', '650', '0', '256GB', '0')
# (621, 'ThinkPad', 'T470', '0', '256GB', '0')
# (622, 'Inspiron', '5570', '1TB', '0', '0')
# (623, 'LifeBook', 'A557', '0', '256GB', '0')
# (624, 'EliteBook', '850', '500GB', '0', '0')
# (625, 'IdeaPad', '320-15IKB', '1TB', '0', '0')
# (626, 'SmartBook', '140', '0', '0', '32GB')
# (627, 'IdeaPad', '320-15IKBN', '0', '128GB', '0')
# (628, 'Q304UA-BHI5T11', '(i5-7200U/6GB/1TB/FHD/W10)', '1TB', '0', '0')
# (629, 'XPS', '15', '0', '256GB', '0')
# (630, 'ZenBook', '3', '0', '512GB', '0')
# (631, 'Inspiron', '7567', '1TB', '256GB', '0')
# (632, 'V330-15IKB', '(i5-8250U/4GB/256GB/FHD/W10)', '0', '256GB', '0')
# (633, 'Ideapad', '320-15ISK', '1TB', '0', '0')
# (634, 'X541NA-GO414T', '(N3350/8GB/1TB/W10)', '1TB', '0', '0')
# (635, 'VivoBook', 'Pro', '1TB', '0', '0')
# (636, 'XPS', '13', '0', '256GB', '0')
# (637, 'IdeaPad', '100S-14IBR', '0', '0', '32GB')
# (638, 'Thinkpad', 'Yoga', '0', '256GB', '0')
# (639, 'XPS', '15', '0', '1TB', '0')
# (640, 'Legion', 'Y520-15IKBN', '1TB', '128GB', '0')
# (641, '17-AK091ND', '(A9-9420/8GB/1TB/W10)', '1TB', '0', '0')
# (642, 'ThinkPad', 'X1', '0', '512GB', '0')
# (643, 'ROG', 'GL553VE-FY022', '1TB', '0', '0')
# (644, 'Extensa', 'EX2540', '500GB', '0', '0')
# (645, 'IdeaPad', '100S-14IBR', '0', '0', '32GB')
# (646, 'Swift', '3', '0', '256GB', '0')
# (647, 'Blade', 'Pro', '0', '256GB', '0')
# (648, 'Portege', 'Z30-C-16J', '0', '256GB', '0')
# (649, 'Thinkpad', 'X270', '0', '256GB', '0')
# (650, 'ROG', 'G701VI', '0', '512GB', '0')
# (651, 'A715-71G-59DH', '(i5-7300HQ/8GB/1TB/GeForce', '1TB', '0', '0')
# (652, 'XPS', '13', '0', '256GB', '0')
# (653, 'GL62M', '7REX', '1TB', '128GB', '0')
# (654, '250', 'G6', '500GB', '0', '0')
# (655, 'Tecra', 'A50-D-11M', '500GB', '0', '0')
# (656, 'Inspiron', '5570', '0', '256GB', '0')
# (657, 'Inspiron', '5570', '2TB', '256GB', '0')
# (658, 'IdeaPad', 'Y700-15ISK', '1TB', '128GB', '0')
# (659, 'Alienware', '17', '1TB', '512GB', '0')
# (660, 'Latitude', 'E7470', '0', '256GB', '0')
# (661, 'Ideapad', '320-15IAP', '500GB', '0', '0')
# (662, 'IdeaPad', '320-15ISK', '500GB', '0', '0')
# (663, '15-ay047nv', '(i3-6006U/6GB/1TB/Radeon', '1TB', '0', '0')
# (664, 'GP72VR', 'Leopard', '1TB', '128GB', '0')
# (665, 'Satellite', 'Pro', '0', '128GB', '0')
# (666, 'Latitude', '3580', '1TB', '0', '0')
# (667, '15-bs012nv', '(i7-7500U/8GB/1TB/Radeon', '1TB', '0', '0')
# (668, 'Tecra', 'Z50-D-10E', '0', '256GB', '0')
# (669, 'Aspire', '3', '0', '128GB', '0')
# (670, 'Surface', 'Laptop', '0', '256GB', '0')
# (671, 'V310-15ISK', '(i5-7200U/8GB/1TB', '1TB', '128GB', '0')
# (672, 'Yoga', '720-13IKB', '0', '256GB', '0')
# (673, 'IdeaPad', '320-15AST', '0', '128GB', '0')
# (674, 'Pavilion', 'X360', '0', '128GB', '0')
# (675, 'GP62', '7RDX', '1TB', '256GB', '0')
# (676, 'Zenbook', '3', '0', '256GB', '0')
# (677, 'Chromebook', 'X360', '0', '0', '64GB')
# (678, 'Gram', '15Z975', '0', '512GB', '0')
# (679, 'Aspire', 'VX5-591G', '0', '256GB', '0')
# (680, 'GV62M', '7RD', '0', '256GB', '0')
# (681, 'L502NA-GO052T', '(N3350/4GB/128GB/W10)', '0', '128GB', '0')
# (682, 'Alienware', '15', '1TB', '128GB', '0')
# (683, '17-bs000nv', 'I3', '0', '256GB', '0')
# (684, 'Yoga', '730', '0', '512GB', '0')
# (685, 'Alienware', '15', '1TB', '256GB', '0')
# (686, '250', 'G6', '500GB', '0', '0')
# (687, 'Inspiron', '3567', '1TB', '0', '0')
# (688, '17-Y002nv', '(A10-9600P/6GB/2TB/Radeon', '2TB', '0', '0')
# (689, 'V110-15ISK', '(3855U/4GB/500GB/W10)', '500GB', '0', '0')
# (690, 'Chromebook', '14', '0', '0', '32GB')
# (691, 'IdeaPad', '520s-14IKB', '0', '256GB', '0')
# (692, 'ZBook', '17', '500GB', '0', '0')
# (693, 'ThinkPad', 'X1', '0', '256GB', '0')
# (694, 'Satellite', 'Pro', '0', '256GB', '0')
# (695, 'TravelMate', 'B117-M', '0', '0', '32GB')
# (696, 'Yoga', '910-13IKB', '0', '512GB', '0')
# (697, 'Chromebook', 'Flip', '0', '0', '64GB')
# (698, 'Portege', 'Z30T-C-133', '0', '512GB', '0')
# (699, '15-bs011nv', '(i7-7500U/4GB/500GB/Radeon', '500GB', '0', '0')
# (700, 'Inspiron', '5577', '1TB', '0', '0')
# (701, 'IdeaPad', '320-15AST', '0', '256GB', '0')
# (702, 'IdeaPad', '320-15ABR', '1TB', '0', '0')
# (703, 'V310-15IKB', '(i5-7200U/4GB/1TB/FHD/W10)', '1TB', '0', '0')
# (704, 'V310-15ISK', '(i3-6006U/4GB/500GB/No', '500GB', '0', '0')
# (705, 'Vostro', '5568', '0', '256GB', '0')
# (706, 'Spin', '5', '0', '256GB', '0')
# (707, 'ThinkPad', 'P51s', '0', '512GB', '0')
# (708, 'Thinkpad', 'T460p', '0', '256GB', '0')
# (709, '17-ak002nv', '(A10-9620P/6GB/2TB/Radeon', '2TB', '0', '0')
# (710, 'Legion', 'Y520-15IKBN', '1TB', '128GB', '0')
# (711, 'Latitude', '5480', '0', '256GB', '0')
# (712, 'Vostro', '5568', '1TB', '0', '0')
# (713, 'VivoBook', 'E403NA', '0', '0', '32GB')
# (714, 'Latitude', '5580', '0', '512GB', '0')
# (715, 'Thinkpad', 'E470', '0', '256GB', '0')
# (716, 'Latitude', '5580', '0', '256GB', '0')
# (717, '110-15ACL', '(A6-7310/4GB/500GB/W10)', '500GB', '0', '0')
# (718, 'Smartbook', '142', '32GB', '0', '0')
# (719, 'ProBook', '470', '0', '256GB', '0')
# (720, 'ThinkPad', 'X1', '0', '512GB', '0')
# (721, 'Pavilion', 'X360', '0', '256GB', '0')
# (722, 'ThinkPad', 'T470s', '0', '256GB', '0')
# (723, 'Alienware', '17', '1TB', '1TB', '0')
# (724, 'GL72M', '7REX', '1TB', '128GB', '0')
# (725, 'V310-15IKB', '(i5-7200U/4GB/1TB/No', '1TB', '0', '0')
# (726, 'Inspiron', '5570', '1TB', '128GB', '0')
# (727, 'Inspiron', '5378', '1TB', '0', '0')
# (728, 'Inspiron', '5567', '1TB', '0', '0')
# (729, '15-BW037na', '(A9-9420/4GB/1TB/Radeon', '1TB', '0', '0')
# (730, 'Predator', '17', '1TB', '128GB', '0')
# (731, 'Inspiron', '3567', '1TB', '0', '0')
# (732, '15-BW091ND', '(A9-9420/6GB/1TB', '1TB', '128GB', '0')
# (733, 'Extensa', 'EX2540-58KR', '500GB', '0', '0')
# (734, 'ThinkPad', '13', '0', '256GB', '0')
# (735, 'V310-15IKB', '(i7-7500U/4GB/1TB/FHD/W10)', '1TB', '0', '0')
# (736, 'ZBook', '15', '0', '256GB', '0')
# (737, 'Inspiron', '5379', '1TB', '0', '0')
# (738, 'GS63VR', '7RF', '1TB', '256GB', '0')
# (739, 'Aspire', 'ES1-572', '500GB', '0', '0')
# (740, 'Inspiron', '7560', '1TB', '128GB', '0')
# (741, 'Vostro', '3568', '0', '256GB', '0')
# (742, 'Tecra', 'X40-D-10G', '0', '256GB', '0')
# (743, 'Flex', '5', '0', '256GB', '0')
# (744, 'Thinkpad', 'P51s', '0', '1TB', '0')
# (745, 'Chromebook', '14', '0', '0', '32GB')
# (746, 'Notebook', '9', '0', '256GB', '0')
# (747, '250', 'G6', '0', '256GB', '0')
# (748, 'Latitude', '5480', '0', '256GB', '0')
# (749, 'Zbook', '17', '0', '256GB', '0')
# (750, 'N23', '(N3060/4GB/128GB/W10)', '0', '128GB', '0')
# (751, 'EliteBook', '850', '0', '256GB', '0')
# (752, 'X550VX-XX015D', '(i5-6300HQ/4GB/1TB/GeForce', '1TB', '0', '0')
# (753, 'Thinkpad', 'T460', '0', '180GB', '0')
# (754, 'Pro', 'P2540UA-XO0192R', '0', '256GB', '0')
# (755, 'Yoga', '900-13ISK', '0', '256GB', '0')
# (756, '15-cb003na', '(i5-7300HQ/8GB/1TB', '1TB', '128GB', '0')
# (757, 'ZBook', '15', '0', '256GB', '0')
# (758, 'Alienware', '17', '1TB', '256GB', '0')
# (759, 'Aspire', '3', '0', '256GB', '0')
# (760, 'Legion', 'Y520-15IKBN', '1TB', '128GB', '0')
# (761, 'Latitude', '7280', '0', '256GB', '0')
# (762, 'Pixelbook', '(Core', '0', '256GB', '0')
# (763, 'Zenbook', 'UX330UA-AH5Q', '0', '256GB', '0')
# (764, 'Latitude', '3380', '500GB', '0', '0')
# (765, 'TravelMate', 'P238-M', '0', '128GB', '0')
# (766, 'X751NV-TY001', '(N4200/4GB/1TB/GeForce', '1TB', '0', '0')
# (767, 'Inspiron', '7559', '1TB', '128GB', '0')
# (768, 'Notebook', '9', '0', '256GB', '0')
# (769, 'Aspire', 'A315-31', '1TB', '0', '0')
# (770, 'Inspiron', '5567', '0', '256GB', '0')
# (771, 'Notebook', '9', '0', '256GB', '0')
# (772, 'Tecra', 'A40-C-1E5', '0', '128GB', '0')
# (773, 'Inspiron', '7567', '1TB', '0', '0')
# (774, 'EliteBook', '820', '0', '256GB', '0')
# (775, 'Q524UQ-BHI7T15', '(i7-7500U/12GB/2TB/GeForce', '2TB', '0', '0')
# (776, 'Thinkpad', 'P50', '0', '512GB', '0')
# (777, 'Swift', '3', '0', '128GB', '0')
# (778, 'Blade', 'Pro', '0', '512GB', '0')
# (779, 'Vivobook', 'Max', '0', '128GB', '0')
# (780, 'Alienware', '17', '1TB', '1TB', '0')
# (781, 'Rog', 'G752VS-BA171T', '1TB', '256GB', '0')
# (782, 'Tecra', 'Z40-C-161', '0', '512GB', '0')
# (783, 'IdeaPad', '110-15IBR', '1TB', '0', '0')
# (784, 'ThinkPad', 'T470s', '0', '512GB', '0')
# (785, 'GS43VR', '7RE', '1TB', '256GB', '0')
# (786, 'GL62M', '(i5-7300HQ/8GB/1TB', '1TB', '128GB', '0')
# (787, 'Legion', 'Y520-15IKBN', '1TB', '0', '0')
# (788, 'Predator', 'G9-793', '1TB', '256GB', '0')
# (789, 'Inspiron', '7567', '0', '256GB', '0')
# (790, 'FX502VM-DM560T', '(i7-7700HQ/8GB/1TB', '1TB', '128GB', '0')
# (791, 'K146', '(N3350/4GB/32GB/W10)', '0', '0', '32GB')
# (792, 'ThinkPad', 'Yoga', '0', '512GB', '0')
# (793, 'Yoga', '510-15IKB', '0', '256GB', '0')
# (794, 'MacBook', '12"', '0', '0', '512GB')
# (795, 'ThinkPad', 'X1', '0', '256GB', '0')
# (796, 'R417NA-RS01', '(N3350/4GB/32GB/W10)', '0', '0', '32GB')
# (797, 'Latitude', '3580', '0', '128GB', '0')
# (798, 'Yoga', '910-13IKB', '0', '256GB', '0')
# (799, 'Vostro', '5568', '0', '256GB', '0')
# (800, 'ZBook', '17', '0', '256GB', '0')
# (801, 'Pro', 'P2540UA-XS51', '0', '256GB', '0')
# (802, 'XPS', '13', '0', '256GB', '0')
# (803, 'XPS', '15', '0', '256GB', '0')
# (804, 'Latitude', '3180', '0', '128GB', '0')
# (805, 'EliteBook', '820', '0', '256GB', '0')
# (806, 'Satellite', 'Pro', '500GB', '0', '0')
# (807, '15-ba043na', '(A12-9700P/8GB/2TB/W10)', '2TB', '0', '0')
# (808, 'Inspiron', '7567', '0', '512GB', '0')
# (809, 'IdeaPad', '310-15IKB', '1TB', '0', '0')
# (810, 'Omen', '17-an012dx', '1TB', '0', '0')
# (811, 'GE72MVR', '7RG', '1TB', '512GB', '0')
# (812, 'Notebook', '9', '0', '256GB', '0')
# (813, 'Vostro', '5568', '1TB', '0', '0')
# (814, 'Vostro', '3568', '0', '256GB', '0')
# (815, 'Thinkpad', 'T470s', '0', '256GB', '0')
# (816, 'Blade', 'Stealth', '0', '512GB', '0')
# (817, 'Chromebook', '11', '0', '0', '16GB')
# (818, 'Alienware', '17', '1TB', '128GB', '0')
# (819, 'Latitude', '3480', '500GB', '0', '0')
# (820, 'V110-15ISK', '(i3-6006U/4GB/500GB/W10)', '500GB', '0', '0')
# (821, 'Tecra', 'X40-D-10Z', '0', '128GB', '0')
# (822, 'Thinkpad', 'X1', '0', '512GB', '0')
# (823, 'GL62M', '7RD', '0', '256GB', '0')
# (824, 'ThinkPad', 'X1', '0', '0', '256GB')
# (825, 'Satellite', 'Pro', '0', '128GB', '0')
# (826, 'ZenBook', 'Flip', '0', '256GB', '0')
# (827, 'Latitude', '3480', '500GB', '0', '0')
# (828, 'Chromebook', '11', '0', '0', '32GB')
# (829, 'Swift', '3', '0', '128GB', '0')
# (830, 'Blade', 'Pro', '0', '512GB', '0')
# (831, 'Thinkpad', 'X1', '0', '512GB', '0')
# (832, 'VivoBook', 'Max', '1TB', '0', '0')
# (833, 'Thinkpad', 'T460', '0', '256GB', '0')
# (834, 'ThinkPad', 'T470s', '0', '256GB', '0')
# (835, 'Alienware', '15', '1TB', '256GB', '0')
# (836, 'Rog', 'GL702VS-BA023T', '1TB', '256GB', '0')
# (837, 'Satellite', 'Pro', '500GB', '0', '0')
# (838, 'N42-20', 'Chromebook', '0', '0', '16GB')
# (839, 'R558UA-DM966T', '(i5-7200U/8GB/128GB/FHD/W10)', '128GB', '0', '0')
# (840, 'Rog', 'GL702VM-GC017T', '1TB', '512GB', '0')
# (841, 'Alienware', '17', '1TB', '512GB', '0')
# (842, 'ProBook', '470', '1TB', '0', '0')
# (843, 'Vostro', '3568', '0', '128GB', '0')
# (844, 'EliteBook', '840', '0', '512GB', '0')
# (845, 'Vostro', '3568', '0', '256GB', '0')
# (846, 'Chromebook', 'X360', '0', '0', '32GB')
# (847, 'ZenBook', 'UX310UQ-GL026T', '0', '512GB', '0')
# (848, 'EliteBook', 'x360', '0', '256GB', '0')
# (849, 'EliteBook', '840', '0', '512GB', '0')
# (850, '250', 'G6', '0', '128GB', '0')
# (851, 'Rog', 'GL502VM-DS74', '1TB', '128GB', '0')
# (852, 'Inspiron', '5767', '1TB', '0', '0')
# (853, 'ThinkPad', 'T470p', '0', '256GB', '0')
# (854, 'K556UR-DM621T', '(i7-7500U/8GB/256GB/GeForce', '0', '256GB', '0')
# (855, 'Latitude', '5580', '0', '128GB', '0')
# (856, 'X541NA', '(N4200/4GB/1TB/W10)', '1TB', '0', '0')
# (857, 'EliteBook', 'x360', '0', '256GB', '0')
# (858, 'Inspiron', '5368', '1TB', '0', '0')
# (859, 'IdeaPad', '110-15ISK', '1TB', '0', '0')
# (860, 'ThinkPad', 'E570', '1TB', '0', '0')
# (861, 'EliteBook', '850', '0', '256GB', '0')
# (862, 'Portege', 'X30-D-10X', '0', '128GB', '0')
# (863, 'Legion', 'Y520-15IKBN', '1TB', '0', '0')
# (864, 'XPS', '13', '0', '512GB', '0')
# (865, 'Probook', '450', '500GB', '0', '0')
# (866, 'Portégé', 'Z30-C-188', '0', '256GB', '0')
# (867, 'ThinkPad', 'Yoga', '0', '256GB', '0')
# (868, 'TMX349-G2-M-50FS', '(i5-7200U/8GB/256GB/FHD/W10)', '0', '256GB', '0')
# (869, 'Precision', '3520', '1TB', '0', '0')
# (870, 'ThinkPad', 'L570', '500GB', '0', '0')
# (871, 'IdeaPad', '110-15ISK', '1TB', '0', '0')
# (872, 'Tecra', 'A50-D-11D', '0', '256GB', '0')
# (873, 'Thinkpad', '13', '0', '180GB', '0')
# (874, 'Notebook', '9', '0', '256GB', '0')
# (875, 'Latitude', '7280', '0', '256GB', '0')
# (876, 'X541NA-GO121', '(N4200/4GB/1TB/Linux)', '1TB', '0', '0')
# (877, 'Mi', 'Notebook', '0', '256GB', '0')
# (878, 'Vostro', '5568', '1TB', '128GB', '0')
# (879, 'ProBook', '450', '0', '256GB', '0')
# (880, 'EliteBook', 'x360', '0', '256GB', '0')
# (881, 'Pavilion', 'x360', '500GB', '0', '0')
# (882, 'VivoBook', 'L402NA', '0', '0', '32GB')
# (883, 'IdeaPad', '510-15ISK', '1TB', '0', '0')
# (884, 'Inspiron', '3552', '500GB', '0', '0')
# (885, 'EliteBook', 'x360', '0', '256GB', '0')
# (886, 'Vostro', '3568', '1TB', '0', '0')
# (887, 'Rog', 'GL753VD-GC082T', '1TB', '128GB', '0')
# (888, 'Chromebook', 'C731-C78G', '0', '0', '32GB')
# (889, 'IdeaPad', '110-17ACL', '500GB', '0', '0')
# (890, 'Probook', '640', '0', '128GB', '0')
# (891, 'Envy', 'x360', '0', '256GB', '0')
# (892, 'Notebook', '9', '0', '256GB', '0')
# (893, 'ThinkPad', 'T470s', '0', '256GB', '0')
# (894, 'GS73VR', 'Stealth', '2TB', '512GB', '0')
# (895, 'Portege', 'X30-D-10V', '0', '256GB', '0')
# (896, 'Inspiron', '7567', '1TB', '0', '0')
# (897, 'ProBook', '450', '1TB', '0', '0')
# (898, 'Vostro', '3568', '1TB', '0', '0')
# (899, 'Latitude', '5580', '500GB', '0', '0')
# (900, 'XPS', '13', '0', '512GB', '0')
# (901, 'G701VO-IH74K', '(i7-6820HK/32GB/2x', '0', '256GB', '0')
# (902, 'XPS', '13', '0', '256GB', '0')
# (903, 'ThinkPad', 'X1', '0', '0', '256GB')
# (904, 'ThinkPad', 'T570', '0', '512GB', '0')
# (905, 'Gram', '15Z970', '0', '512GB', '0')
# (906, 'Elitebook', '820', '0', '512GB', '0')
# (907, 'Chromebook', 'CB5-571-C1DZ', '0', '0', '16GB')
# (908, 'IdeaPad', 'Y700-15ISK', '1TB', '128GB', '0')
# (909, 'Gram', '14Z970', '0', '512GB', '0')
# (910, 'Latitude', '5480', '0', '256GB', '0')
# (911, 'Elitebook', 'Folio', '0', '240GB', '0')
# (912, 'IdeaPad', '510-15IKB', '0', '256GB', '0')
# (913, 'ProBook', '450', '0', '256GB', '0')
# (914, 'Aspire', 'E5-575', '1TB', '0', '0')
# (915, 'ThinkPad', '13', '0', '128GB', '0')
# (916, 'Probook', '430', '0', '256GB', '0')
# (917, 'GE72VR', '6RF', '1TB', '256GB', '0')
# (918, 'Inspiron', '7567', '1TB', '128GB', '0')
# (919, 'GL62M', '7RD', '1TB', '128GB', '0')
# (920, 'Vostro', '3568', '1TB', '0', '0')
# (921, 'EliteBook', '850', '0', '256GB', '0')
# (922, 'Envy', '13-AB077cl', '0', '256GB', '0')
# (923, 'Tecra', 'Z50-C-140', '0', '256GB', '0')
# (924, 'ThinkPad', 'Yoga', '0', '512GB', '0')
# (925, 'Latitude', '3580', '500GB', '0', '0')
# (926, 'Thinkpad', 'X270', '0', '256GB', '0')
# (927, 'Probook', '650', '0', '256GB', '0')
# (928, 'Vostro', '3568', '1TB', '0', '0')
# (929, 'ProBook', '640', '500GB', '0', '0')
# (930, 'IdeaPad', '320-15IAP', '1TB', '0', '0')
# (931, 'EliteBook', '820', '500GB', '0', '0')
# (932, '250', 'G6', '1TB', '0', '0')
# (933, 'Yoga', '900-13ISK', '0', '1TB', '0')
# (934, 'Tecra', 'Z40-C-12X', '0', '128GB', '0')
# (935, 'EliteBook', '820', '0', '256GB', '0')
# (936, 'Vostro', '3568', '1TB', '0', '0')
# (937, 'GP62M', 'Leopard', '1TB', '128GB', '0')
# (938, 'Latitude', '7480', '0', '256GB', '0')
# (939, 'Alienware', '17', '1TB', '512GB', '0')
# (940, 'Omen', '17-W006na', '1TB', '128GB', '0')
# (941, 'X751SV-TY001T', '(N3710/4GB/1TB/GeForce', '1TB', '0', '0')
# (942, 'TravelMate', 'P259-G2', '500GB', '0', '0')
# (943, 'Tecra', 'A50-C-1ZV', '0', '256GB', '0')
# (944, 'Yoga', '700-11ISK', '0', '256GB', '0')
# (945, 'IdeaPad', 'Y700-15ACZ', '1TB', '512GB', '0')
# (946, 'Latitude', '7280', '0', '256GB', '0')
# (947, 'IdeaPad', '310-15IKB', '1TB', '0', '0')
# (948, 'Insprion', '5767', '1TB', '0', '0')
# (949, 'Chromebook', '14', '0', '0', '32GB')
# (950, 'ZBook', 'Studio', '0', '8GB', '0')
# (951, 'Latitude', '7480', '0', '256GB', '0')
# (952, 'Portege', 'Z30-C-1CW', '0', '256GB', '0')
# (953, 'Chromebook', 'Flip', '0', '0', '64GB')
# (954, 'Thinkpad', 'T460', '0', '256GB', '0')
# (955, 'Alienware', '17', '1TB', '512GB', '0')
# (956, 'XPS', '13', '0', '256GB', '0')
# (957, 'ProBook', 'x360', '0', '256GB', '0')
# (958, 'XPS', '13', '0', '256GB', '0')
# (959, 'Chromebook', 'C738T-C2EJ', '0', '0', '32GB')
# (960, 'Portege', 'Z30-C-16Z', '0', '256GB', '0')
# (961, 'ThinkPad', 'X270', '0', '256GB', '0')
# (962, 'Aspire', 'F5-573G-510L', '1TB', '128GB', '0')
# (963, 'Portege', 'X20W-D-10V', '0', '512GB', '0')
# (964, 'ProBook', '450', '1TB', '0', '0')
# (965, 'Inspiron', '3567', '1TB', '0', '0')
# (966, 'Latitude', '5580', '500GB', '0', '0')
# (967, 'ProBook', '450', '500GB', '0', '0')
# (968, 'Alienware', '17', '1TB', '256GB', '0')
# (969, 'IdeaPad', '310-15IKB', '0', '256GB', '0')
# (970, 'XPS', '13', '0', '512GB', '0')
# (971, 'Latitude', 'E7470', '0', '256GB', '0')
# (972, 'Alienware', '17', '1TB', '256GB', '0')
# (973, 'Tecra', 'A40-C-1DF', '0', '256GB', '0')
# (974, 'Rog', 'Strix', '1TB', '256GB', '0')
# (975, 'Probook', '450', '1TB', '128GB', '0')
# (976, 'ThinkPad', 'T460', '0', '0', '0')
# (977, 'Q534UX-BHI7T19', '(i7-7500U/16GB/2TB', '2TB', '512GB', '0')
# (978, '15-bs053od', '(i7-7500U/6GB/1TB/W10)', '1TB', '0', '0')
# (979, 'Rog', 'GL753VE-DS74', '1TB', '256GB', '0')
# (980, 'Inspiron', '7579', '0', '512GB', '0')
# (981, 'Portege', 'Z30-C-1CV', '0', '128GB', '0')
# (982, 'IdeaPad', '320-15ABR', '0', '256GB', '0')
# (983, 'LifeBook', 'A556', '0', '256GB', '0')
# (984, 'Tecra', 'A40-C-1KF', '500GB', '0', '0')
# (985, 'Inspiron', '3567', '500GB', '0', '0')
# (986, 'Probook', '450', '1TB', '0', '0')
# (987, 'Legion', 'Y520-15IKBN', '1TB', '128GB', '0')
# (988, 'Inspiron', '5567', '1TB', '0', '0')
# (989, 'Latitude', '5480', '0', '128GB', '0')
# (990, 'EliteBook', 'Folio', '0', '512GB', '0')
# (991, '15-bs005nv', '(i3-6006U/4GB/1TB', '1TB', '128GB', '0')
# (992, 'V110-15IAP', '(N3350/4GB/128GB/No', '0', '128GB', '0')
# (993, 'ThinkPad', 'T560', '0', '256GB', '0')
# (994, 'Inspiron', '5378', '0', '256GB', '0')
# (995, 'ZenBook', 'UX310UA-FB485T', '0', '256GB', '0')
# (996, 'Spectre', '13-V111dx', '0', '256GB', '0')
# (997, 'Aspire', 'ES1-533', '500GB', '0', '0')
# (998, 'Rog', 'GL553VE-DS74', '1TB', '256GB', '0')
# (999, 'EliteBook', '840', '0', '512GB', '0')
# (1000, 'Nitro', '5', '1TB', '128GB', '0')
# (1001, 'ENVY', '-', '0', '256GB', '0')
# (1002, 'Vostro', '3568', '0', '128GB', '0')
# (1003, 'Probook', '440', '500GB', '0', '0')
# (1004, 'Portege', 'Z30-C-16H', '0', '128GB', '0')
# (1005, 'EliteBook', '840', '0', '256GB', '0')
# (1006, 'ProBook', '640', '0', '256GB', '0')
# (1007, 'EliteBook', '1040', '0', '256GB', '0')
# (1008, 'ProBook', '440', '0', '256GB', '0')
# (1009, 'Probook', '440', '500GB', '0', '0')
# (1010, 'Inspiron', '7567', '0', '0', '0')
# (1011, 'EliteBook', '820', '500GB', '0', '0')
# (1012, 'Elitebook', '840', '0', '256GB', '0')
# (1013, 'EliteBook', '840', '0', '256GB', '0')
# (1014, 'Probook', '430', '500GB', '0', '0')
# (1015, 'Portege', 'A30-C-1CZ', '0', '256GB', '0')
# (1016, 'ProBook', '450', '0', '256GB', '0')
# (1017, 'ThinkPad', 'P70', '0', '512GB', '0')
# (1018, 'Tecra', 'Z40-C-12Z', '0', '256GB', '0')
# (1019, 'EliteBook', '1040', '0', '256GB', '0')
# (1020, 'Inspiron', '5568', '1TB', '0', '0')
# (1021, 'Portégé', 'Z30-C-16K', '0', '256GB', '0')
# (1022, 'Spectre', '13-V100nv', '0', '256GB', '0')
# (1023, 'ProBook', '440', '0', '256GB', '0')
# (1024, 'Latitude', 'E5570', '500GB', '0', '0')
# (1025, 'Elitebook', '820', '0', '256GB', '0')
# (1026, 'ProBook', '650', '500GB', '0', '0')
# (1027, 'ProBook', '640', '500GB', '0', '0')
# (1028, 'XPS', '13', '0', '256GB', '0')
# (1029, 'Probook', '470', '0', '256GB', '0')
# (1030, 'ProBook', '440', '0', '256GB', '0')
# (1031, 'Aspire', '3', '1TB', '0', '0')
# (1032, 'GL72M', '7RDX', '1TB', '128GB', '0')
# (1033, 'Probook', '640', '0', '256GB', '0')
# (1034, 'EliteBook', '850', '0', '256GB', '0')
# (1035, 'EliteBook', '820', '0', '256GB', '0')
# (1036, 'ProBook', '450', '500GB', '0', '0')
# (1037, 'Tecra', 'Z40-C-136', '0', '256GB', '0')
# (1038, 'Latitude', 'E5570', '0', '256GB', '0')
# (1039, 'ProBook', '440', '0', '256GB', '0')
# (1040, 'Yoga', '500-15ISK', '0', '256GB', '0')
# (1041, 'V142', '(X5-Z8350/2GB/32GB/W10)', '0', '0', '32GB')
# (1042, 'Tecra', 'A50-C-218', '0', '256GB', '0')
# (1043, 'Thinkpad', 'L560', '0', '256GB', '0')
# (1044, 'EliteBook', '840', '500GB', '0', '0')
# (1045, 'EliteBook', '850', '500GB', '256GB', '0')
# (1046, 'EliteBook', '1040', '0', '256GB', '0')
# (1047, 'GT72S', 'Dominator', '1TB', '256GB', '0')
# (1048, 'IdeaPad', 'Y900-17ISK', '1TB', '128GB', '0')
# (1049, 'Chromebook', 'C202SA', '0', '0', '16GB')
# (1050, 'ThinkPad', 'X1', '0', '256GB', '0')
# (1051, 'Noteb', 'Pav', '1TB', '0', '0')
# (1052, 'Inspiron', '5578', '0', '256GB', '0')
# (1053, 'ProBook', '450', '0', '256GB', '0')
# (1054, 'XPS', '13', '0', '1TB', '0')
# (1055, 'ProBook', '650', '500GB', '0', '0')
# (1056, '250', 'G5', '500GB', '0', '0')
# (1057, 'Aspire', 'ES1-523', '1TB', '0', '0')
# (1058, 'Inspiron', '7378', '0', '256GB', '0')
# (1059, 'GT62VR', '6RD', '1TB', '256GB', '0')
# (1060, 'ProBook', '450', '0', '256GB', '0')
# (1061, 'Rog', 'G752VL-GC088D', '1TB', '0', '0')
# (1062, 'Inspiron', '3567', '1TB', '0', '0')
# (1063, 'Inspiron', '5567', '2TB', '0', '0')
# (1064, 'GS63VR', '6RF', '1TB', '256GB', '0')
# (1065, 'XPS', '13', '0', '256GB', '0')
# (1066, 'ROG', 'G701VO', '0', '1TB', '0')
# (1067, 'Inspiron', '5368', '0', '256GB', '0')
# (1068, 'Alienware', '15', '1TB', '256GB', '0')
# (1069, 'MacBook', '12"', '0', '0', '256GB')
# (1070, 'Latitude', '3570', '500GB', '0', '0')
# (1071, 'ProBook', '650', '500GB', '0', '0')
# (1072, 'EliteBook', '820', '0', '256GB', '0')
# (1073, 'ProBook', '430', '0', '256GB', '0')
# (1074, 'ThinkPad', 'Yoga', '0', '256GB', '0')
# (1075, 'IdeaPad', '300-17ISK', '1.0TB', '0', '0')
# (1076, 'Ideapad', '700-15ISK', '1TB', '0', '0')
# (1077, 'GT72VR', 'Dominator', '1TB', '256GB', '0')
# (1078, 'V110-15ISK', '(i5-6200U/4GB/500GB/W10)', '500GB', '0', '0')
# (1079, 'Probook', '650', '500GB', '0', '0')
# (1080, 'Yoga', '900S-12ISK', '0', '512GB', '0')
# (1081, 'IdeaPad', 'Y900-17ISK', '0', '512GB', '0')
# (1082, 'Yoga', 'Book', '0', '0', '64GB')
# (1083, 'Spectre', 'x360', '0', '512GB', '0')
# (1084, 'Vostro', '3568', '0', '256GB', '0')
# (1085, 'EliteBook', '840', '500GB', '0', '0')
# (1086, 'ZBook', '15u', '0', '256GB', '0')
# (1087, 'ThinkPad', 'T460', '0', '180GB', '0')
# (1088, 'Chromebook', '13', '0', '0', '32GB')
# (1089, 'Aspire', 'ES1-523', '500GB', '0', '0')
# (1090, 'Inspiron', '3552', '500GB', '0', '0')
# (1091, '250', 'G6', '1TB', '0', '0')
# (1092, 'Rog', 'GL702VM-GC354T', '1TB', '256GB', '0')
# (1093, 'Inspiron', '5370', '0', '256GB', '0')
# (1094, 'Elitebook', '820', '0', '128GB', '0')
# (1095, 'Aspire', 'F5-573G', '1TB', '256GB', '0')
# (1096, 'Inspiron', '5567', '1TB', '0', '0')
# (1097, 'GS70', 'Stealth', '0', '256GB', '0')
# (1098, '250', 'G5', '1TB', '0', '0')
# (1099, 'G752VY-GC162T', '(i7-6700HQ/16GB/1TB', '1TB', '128GB', '0')
# (1100, 'Latitude', 'E5270', '500GB', '0', '0')
# (1101, 'Latitude', 'E5270', '0', '128GB', '0')
# (1102, 'Chromebook', '15', '0', '16GB', '0')
# (1103, 'ZBook', '17', '1TB', '0', '0')
# (1104, 'Legion', 'Y520-15IKBN', '0', '512GB', '0')
# (1105, 'Latitude', 'E5270', '0', '256GB', '0')
# (1106, 'GE72', 'Apache', '1TB', '128GB', '0')
# (1107, 'Yoga', '500-15ISK', '0', '256GB', '0')
# (1108, '15-bw011nv', '(A6-9220/4GB/1TB/FHD/W10)', '1TB', '0', '0')
# (1109, 'Rog', 'GL552VW-CN470T', '1TB', '128GB', '0')
# (1110, 'EliteBook', '1030', '0', '256GB', '0')
# (1111, 'Vostro', '3559', '500GB', '0', '0')
# (1112, 'V110-15ISK', '(i3-6006U/4GB/128GB/W10)', '0', '128GB', '0')
# (1113, 'Spectre', 'Pro', '0', '512GB', '0')
# (1114, 'Yoga', 'Book', '0', '0', '64GB')
# (1115, 'XPS', '13', '0', '256GB', '0')
# (1116, 'IdeaPad', 'Y900-17ISK', '0', '256GB', '0')
# (1117, 'Blade', 'Stealth', '0', '256GB', '0')
# (1118, 'Portege', 'X30-D-10K', '0', '512GB', '0')
# (1119, 'Rog', 'GL752VW-T4308T', '1TB', '128GB', '0')
# (1120, 'V131', '(X5-Z8350/4GB/32GB/FHD/W10)', '0', '0', '32GB')
# (1121, 'Spectre', 'Pro', '0', '256GB', '0')
# (1122, 'EliteBook', '1040', '0', '256GB', '0')
# (1123, 'Latitude', 'E5570', '500GB', '0', '0')
# (1124, 'VivoBook', 'Max', '1TB', '0', '0')
# (1125, 'ThinkPad', 'Yoga', '0', '256GB', '0')
# (1126, 'Yoga', 'Book', '0', '0', '64GB')
# (1127, 'EliteBook', '820', '0', '256GB', '0')
# (1128, 'Legion', 'Y520-15IKBN', '1TB', '128GB', '0')
# (1129, 'Omen', '-', '1TB', '128GB', '0')
# (1130, '15-bs078cl', '(i7-7500U/8GB/2TB/W10)', '2TB', '0', '0')
# (1131, 'ThinkPad', 'P40', '0', '512GB', '0')
# (1132, 'L403NA-GA013TS', '(N3350/4GB/32GB/W10)', '0', '0', '32GB')
# (1133, '250', 'G6', '0', '256GB', '0')
# (1134, 'Aspire', 'E5-576G', '1TB', '0', '0')
# (1135, 'IdeaPad', '500-15ISK', '0', '0', '0')
# (1136, 'ZBook', '17', '0', '256GB', '0')
# (1137, 'Inspiron', '5567', '1TB', '0', '0')
# (1138, 'GT72S', 'Dominator', '1TB', '256GB', '0')
# (1139, 'EliteBook', '850', '0', '256GB', '0')
# (1140, 'ThinkPad', 'X1', '0', '512GB', '0')
# (1141, 'GP62M', '7RDX', '1TB', '128GB', '0')
# (1142, 'Spectre', 'Pro', '0', '256GB', '0')
# (1143, 'ZBook', '15', '0', '256GB', '0')
# (1144, 'Spectre', 'Pro', '0', '256GB', '0')
# (1145, 'ZBook', 'Studio', '0', '256GB', '0')
# (1146, 'EliteBook', '820', '0', '256GB', '0')
# (1147, 'Vostro', '5568', '0', '256GB', '0')
# (1148, 'EliteBook', '850', '0', '256GB', '0')
# (1149, 'ThinkPad', 'X1', '0', '256GB', '0')
# (1150, 'V110-15ISK', '(i3-6006U/4GB/1TB/No', '1TB', '0', '0')
# (1151, '15-BA015wm', '(E2-7110/4GB/500GB/W10)', '500GB', '0', '0')
# (1152, 'B51-80', '(i5-6200U/8GB/1TB/Radeon', '1TB', '0', '0')
# (1153, 'Inspiron', '7567', '1TB', '0', '0')
# (1154, 'XPS', '15', '0', '256GB', '0')
# (1155, '15-bw002nv', '(A6-9220/4GB/256GB/Radeon', '0', '256GB', '0')
# (1156, 'GP72M', '7REX', '1TB', '256GB', '0')
# (1157, 'ThinkPad', 'T460s', '0', '512GB', '0')
# (1158, 'B51-80', '(i5-6200U/8GB/1008GB/Radeon', '0', '0', '0')
# (1159, 'Spectre', 'Pro', '0', '512GB', '0')
# (1160, 'ThinkPad', 'T460', '0', '256GB', '0')
# (1161, 'GS40', 'Phantom', '1TB', '256GB', '0')
# (1162, 'Pavilion', '15-cb003nv', '1TB', '0', '0')
# (1163, 'IdeaPad', '310-15ISK', '1TB', '0', '0')
# (1164, '250', 'G4', '500GB', '0', '0')
# (1165, 'Inspiron', '7567', '1TB', '128GB', '0')
# (1166, 'ThinkPad', 'T570', '0', '256GB', '0')
# (1167, '320-15ISK', '(i3-6006U/4GB/1TB/GeForce', '1TB', '0', '0')
# (1168, 'Stream', '14-AX000nv', '0', '0', '32GB')
# (1169, 'PL60', '7RD', '1TB', '0', '0')
# (1170, '250', 'G5', '0', '256GB', '0')
# (1171, 'ProBook', '450', '0', '512GB', '0')
# (1172, 'X553SA-XX021T', '(N3050/4GB/500GB/W10)', '500GB', '0', '0')
# (1173, 'V110-15ISK', '(i5-6200U/4GB/500GB/No', '500GB', '0', '0')
# (1174, 'IdeaPad', '510-15IKB', '1TB', '0', '0')
# (1175, 'UX410UA-GV097T', '(i3-7100U/4GB/256GB/FHD/W10)', '0', '256GB', '0')
# (1176, 'B51-80', '(i7-6500U/4GB/1008GB/FHD/W7)', '0', '0', '0')
# (1177, 'IdeaPad', 'Y700-15ISK', '0', '512GB', '0')
# (1178, 'GS60', 'Ghost', '1TB', '128GB', '0')
# (1179, 'ProBook', '450', '500GB', '0', '0')
# (1180, 'ThinkPad', 'X1', '0', '256GB', '0')
# (1181, 'IdeaPad', '310-15IKB', '0', '256GB', '0')
# (1182, 'Vostro', '5568', '0', '256GB', '0')
# (1183, 'Aspire', '3', '500GB', '0', '0')
# (1184, 'Pavilion', '15-BC000nv', '1TB', '0', '0')
# (1185, 'Rog', 'GL552VW-DM201T', '1TB', '256GB', '0')
# (1186, 'Inspiron', '5578', '0', '512GB', '0')
# (1187, 'Aspire', 'E5-576G', '0', '256GB', '0')
# (1188, 'XPS', '13', '0', '256GB', '0')
# (1189, 'Predator', 'G9-793', '1TB', '256GB', '0')
# (1190, 'Legion', 'Y520-15IKBN', '1TB', '0', '0')
# (1191, 'Chromebook', 'Plus', '0', '0', '32GB')
# (1192, '250', 'G6', '500GB', '0', '0')
# (1193, 'MacBook', '12"', '0', '0', '256GB')
# (1194, 'Inspiron', '7378', '0', '256GB', '0')
# (1195, 'Pavilion', 'Power', '1TB', '128GB', '0')
# (1196, 'V110-15ISK', '(i3-6006U/4GB/1TB/Radeon', '1TB', '0', '0')
# (1197, 'Rog', 'G752VY-GC229T', '1TB', '512GB', '0')
# (1198, 'Aspire', '3', '1TB', '0', '0')
# (1199, 'GS73VR', '7RF', '1TB', '256GB', '0')
# (1200, 'Inspiron', '5567', '0', '128GB', '0')
# (1201, 'IdeaPad', '310-15ISK', '500GB', '0', '0')
# (1202, 'Inspiron', '5579', '0', '512GB', '0')
# (1203, 'XPS', '13', '0', '512GB', '0')
# (1204, 'FX502VM-DM105T', '(i7-6700HQ/8GB/1TB/GeForce', '1TB', '0', '0')
# (1205, 'Inspiron', '5567', '0', '256GB', '0')
# (1206, '15-bs025nv', '(i5-7200U/8GB/256GB/W10)', '0', '256GB', '0')
# (1207, 'IdeaPad', '320-15AST', '500GB', '0', '0')
# (1208, 'Aspire', 'E5-774G', '1TB', '0', '0')
# (1209, 'Rog', 'Strix', '1TB', '256GB', '0')
# (1210, 'MacBook', '12"', '0', '0', '512GB')
# (1211, 'FX502VM-AS73', '(i7-7700HQ/16GB/1TB', '1TB', '128GB', '0')
# (1212, 'GS73VR', 'Stealth', '1TB', '256GB', '0')
# (1213, 'Inspiron', '7579', '0', '256GB', '0')
# (1214, 'ROG', 'Strix', '1TB', '256GB', '0')
# (1215, 'C740-C9QX', '(3205U/2GB/32GB/Chrome', '0', '32GB', '0')
# (1216, 'E5', '774G', '1TB', '0', '0')
# (1217, 'IdeaPad', '320-17IKB', '1TB', '0', '0')
# (1218, 'IdeaPad', 'Y700-15ISK', '1TB', '128GB', '0')
# (1219, 'SP714-51', '(i7-7Y75/8GB/256GB/FHD/W10)', '0', '256GB', '0')
# (1220, 'Thinkpad', 'T560', '0', '256GB', '0')
# (1221, 'GP62MVR', '6RF', '1TB', '128GB', '0')
# (1222, '15-bw009nv', '(A12-9720P/6GB/1TB/Radeon', '1TB', '0', '0')
# (1223, 'Latitude', 'E7270', '0', '256GB', '0')
# (1224, 'Inspiron', '5578', '500GB', '0', '0')
# (1225, 'X540SA-RBPDN09', '(N3710/4GB/1TB/W10)', '1TB', '0', '0')
# (1226, 'XPS', '13', '0', '256GB', '0')
# (1227, 'Vostro', '3568', '1TB', '0', '0')
# (1228, 'IdeaPad', 'Y700-15ISK', '1TB', '128GB', '0')
# (1229, 'GL62M', '7RDX', '1TB', '128GB', '0')
# (1230, 'ThinkPad', 'Yoga', '0', '512GB', '0')
# (1231, 'Blade', 'Pro', '0', '1TB', '0')
# (1232, 'Inspiron', '3567', '1TB', '0', '0')
# (1233, 'GE72VR', 'Apache', '1TB', '256GB', '0')
# (1234, 'MacBook', 'Air', '0', '0', '256GB')
# (1235, '15-bs023nv', '(i3-6006U/4GB/1TB/FHD/W10)', '1TB', '0', '0')
# (1236, 'EliteBook', '840', '0', '256GB', '0')
# (1237, 'Vostro', '3559', '500GB', '0', '0')
# (1238, 'GL62', '6QF', '1TB', '128GB', '0')
# (1239, 'ThinkPad', '13', '0', '512GB', '0')
# (1240, 'IdeaPad', '320-15ABR', '0', '256GB', '0')
# (1241, 'ZenBook', 'UX310UA-WB71', '0', '256GB', '0')
# (1242, 'Aspire', 'ES1-572', '500GB', '0', '0')
# (1243, 'Inspiron', '7779', '0', '512GB', '0')
# (1244, 'EliteBook', '840', '0', '256GB', '0')
# (1245, 'Rog', 'GL553VE-FY052T', '1TB', '256GB', '0')
# (1246, 'Latitude', '5480', '500GB', '0', '0')
# (1247, 'Rog', 'GL502VS', '1TB', '256GB', '0')
# (1248, 'V510-15IKB', '(i5-7200U/8GB/256GB/FHD/No', '0', '256GB', '0')
# (1249, 'XPS', '13', '0', '256GB', '0')
# (1250, 'Inspiron', '3552', '500GB', '0', '0')
# (1251, '255', 'G6', '500GB', '0', '0')
# (1252, 'IdeaPad', '310-15ISK', '0', '128GB', '0')
# (1253, 'ThinkPad', 'L460', '0', '256GB', '0')
# (1254, 'Inspiron', '3552', '500GB', '0', '0')
# (1255, 'X541NA-GO020T', '(N3350/4GB/1TB/W10)', '1TB', '0', '0')
# (1256, 'Rog', 'G752VT-GC073T', '1TB', '128GB', '0')
# (1257, 'Vostro', '3568', '500GB', '0', '0')
# (1258, 'B51-80', '(i7-6500U/8GB/1008GB/Radeon', '0', '0', '0')
# (1259, 'GE62', 'Apache', '1TB', '128GB', '0')
# (1260, 'Yoga', '500-14IBD', '0', '128GB', '0')
# (1261, 'ZenBook', 'UX305CA-UBM1', '0', '512GB', '0')
# (1262, 'Inspiron', '3567', '1TB', '0', '0')
# (1263, 'Aspire', 'ES1-531', '500GB', '0', '0')
# (1264, 'Inspiron', '3552', '500GB', '0', '0')
# (1265, 'IdeaPad', 'Y700-15ISK', '1TB', '0', '0')
# (1266, 'Pavilion', '15-AW003nv', '0', '0', '0')
# (1267, 'Inspiron', '3567', '1TB', '0', '0')
# (1268, 'Stream', '11-Y000na', '0', '0', '32GB')
# (1269, 'X556UJ-XO044T', '(i7-6500U/4GB/500GB/GeForce', '500GB', '0', '0')
# (1270, 'Yoga', '500-14ISK', '0', '128GB', '0')
# (1271, 'Yoga', '900-13ISK', '0', '512GB', '0')
# (1272, 'IdeaPad', '100S-14IBR', '0', '0', '64GB')
# (1273, '15-AC110nv', '(i7-6500U/6GB/1TB/Radeon', '1TB', '0', '0')
# (1274, 'X553SA-XX031T', '(N3050/4GB/500GB/W10)', '500GB', '0', '0')

# %%
select_view_relation = """
    SELECT * from company_have_product;
"""
result = Connection.execute(select_view_relation)
for i in result:
    print(i)
# Out:
# (0, 0)
# (0, 1)
# (1, 2)
# (0, 3)
# (0, 4)
# (2, 5)
# (0, 6)
# (0, 7)
# (3, 8)
# (2, 9)
# (1, 10)
# (1, 11)
# (0, 12)
# (4, 13)
# (0, 14)
# (0, 15)
# (4, 16)
# (0, 17)
# (5, 18)
# (4, 19)
# (3, 20)
# (5, 21)
# (1, 22)
# (4, 23)
# (1, 24)
# (4, 25)
# (0, 26)
# (4, 27)
# (4, 28)
# (1, 29)
# (6, 30)
# (3, 31)
# (1, 32)
# (4, 33)
# (0, 34)
# (5, 35)
# (2, 36)
# (4, 37)
# (1, 38)
# (1, 39)
# (3, 40)
# (4, 41)
# (3, 42)
# (2, 43)
# (4, 44)
# (0, 45)
# (5, 46)
# (3, 47)
# (4, 48)
# (3, 49)
# (5, 50)
# (2, 51)
# (1, 52)
# (1, 53)
# (2, 54)
# (4, 55)
# (1, 56)
# (3, 57)
# (7, 58)
# (3, 59)
# (4, 60)
# (4, 61)
# (5, 62)
# (3, 63)
# (1, 64)
# (3, 65)
# (1, 66)
# (1, 67)
# (5, 68)
# (3, 69)
# (8, 70)
# (4, 71)
# (4, 72)
# (7, 73)
# (2, 74)
# (3, 75)
# (5, 76)
# (4, 77)
# (2, 78)
# (1, 79)
# (4, 80)
# (0, 81)
# (1, 82)
# (5, 83)
# (2, 84)
# (4, 85)
# (1, 86)
# (1, 87)
# (3, 88)
# (4, 89)
# (3, 90)
# (2, 91)
# (1, 92)
# (4, 93)
# (3, 94)
# (2, 95)
# (4, 96)
# (4, 97)
# (3, 98)
# (1, 99)
# (1, 100)
# (1, 101)
# (4, 102)
# (1, 103)
# (8, 104)
# (1, 105)
# (5, 106)
# (3, 107)
# (7, 108)
# (5, 109)
# (3, 110)
# (4, 111)
# (5, 112)
# (1, 113)
# (4, 114)
# (1, 115)
# (1, 116)
# (4, 117)
# (3, 118)
# (3, 119)
# (2, 120)
# (7, 121)
# (5, 122)
# (1, 123)
# (2, 124)
# (1, 125)
# (1, 126)
# (3, 127)
# (4, 128)
# (1, 129)
# (4, 130)
# (4, 131)
# (2, 132)
# (2, 133)
# (1, 134)
# (1, 135)
# (5, 136)
# (3, 137)
# (5, 138)
# (1, 139)
# (2, 140)
# (5, 141)
# (5, 142)
# (9, 143)
# (1, 144)
# (3, 145)
# (1, 146)
# (3, 147)
# (7, 148)
# (2, 149)
# (4, 150)
# (4, 151)
# (5, 152)
# (7, 153)
# (1, 154)
# (1, 155)
# (5, 156)
# (3, 157)
# (4, 158)
# (9, 159)
# (3, 160)
# (2, 161)
# (4, 162)
# (5, 163)
# (2, 164)
# (7, 165)
# (2, 166)
# (4, 167)
# (2, 168)
# (1, 169)
# (10, 170)
# (1, 171)
# (5, 172)
# (9, 173)
# (1, 174)
# (4, 175)
# (2, 176)
# (7, 177)
# (5, 178)
# (1, 179)
# (4, 180)
# (4, 181)
# (5, 182)
# (9, 183)
# (11, 184)
# (4, 185)
# (4, 186)
# (5, 187)
# (2, 188)
# (4, 189)
# (5, 190)
# (12, 191)
# (11, 192)
# (5, 193)
# (4, 194)
# (1, 195)
# (13, 196)
# (1, 197)
# (1, 198)
# (1, 199)
# (4, 200)
# (5, 201)
# (2, 202)
# (5, 203)
# (4, 204)
# (5, 205)
# (4, 206)
# (4, 207)
# (4, 208)
# (5, 209)
# (2, 210)
# (3, 211)
# (1, 212)
# (5, 213)
# (10, 214)
# (4, 215)
# (5, 216)
# (1, 217)
# (4, 218)
# (4, 219)
# (4, 220)
# (5, 221)
# (9, 222)
# (1, 223)
# (4, 224)
# (2, 225)
# (4, 226)
# (3, 227)
# (3, 228)
# (1, 229)
# (3, 230)
# (1, 231)
# (5, 232)
# (4, 233)
# (2, 234)
# (4, 235)
# (2, 236)
# (3, 237)
# (3, 238)
# (2, 239)
# (5, 240)
# (3, 241)
# (3, 242)
# (4, 243)
# (5, 244)
# (4, 245)
# (1, 246)
# (3, 247)
# (1, 248)
# (0, 249)
# (4, 250)
# (3, 251)
# (3, 252)
# (5, 253)
# (2, 254)
# (4, 255)
# (1, 256)
# (1, 257)
# (7, 258)
# (5, 259)
# (4, 260)
# (5, 261)
# (1, 262)
# (4, 263)
# (4, 264)
# (4, 265)
# (3, 266)
# (5, 267)
# (1, 268)
# (5, 269)
# (0, 270)
# (3, 271)
# (4, 272)
# (5, 273)
# (9, 274)
# (4, 275)
# (4, 276)
# (2, 277)
# (5, 278)
# (5, 279)
# (5, 280)
# (4, 281)
# (5, 282)
# (5, 283)
# (2, 284)
# (2, 285)
# (5, 286)
# (3, 287)
# (5, 288)
# (5, 289)
# (2, 290)
# (3, 291)
# (1, 292)
# (4, 293)
# (5, 294)
# (5, 295)
# (2, 296)
# (4, 297)
# (5, 298)
# (3, 299)
# (3, 300)
# (3, 301)
# (5, 302)
# (5, 303)
# (3, 304)
# (5, 305)
# (1, 306)
# (9, 307)
# (5, 308)
# (1, 309)
# (5, 310)
# (4, 311)
# (7, 312)
# (2, 313)
# (3, 314)
# (4, 315)
# (1, 316)
# (5, 317)
# (1, 318)
# (2, 319)
# (1, 320)
# (5, 321)
# (3, 322)
# (1, 323)
# (2, 324)
# (5, 325)
# (2, 326)
# (3, 327)
# (1, 328)
# (4, 329)
# (7, 330)
# (9, 331)
# (3, 332)
# (5, 333)
# (3, 334)
# (1, 335)
# (4, 336)
# (1, 337)
# (3, 338)
# (4, 339)
# (4, 340)
# (5, 341)
# (1, 342)
# (5, 343)
# (4, 344)
# (5, 345)
# (1, 346)
# (4, 347)
# (3, 348)
# (4, 349)
# (4, 350)
# (1, 351)
# (7, 352)
# (1, 353)
# (9, 354)
# (4, 355)
# (5, 356)
# (4, 357)
# (4, 358)
# (4, 359)
# (1, 360)
# (3, 361)
# (5, 362)
# (1, 363)
# (5, 364)
# (1, 365)
# (4, 366)
# (5, 367)
# (4, 368)
# (1, 369)
# (3, 370)
# (2, 371)
# (3, 372)
# (5, 373)
# (4, 374)
# (1, 375)
# (5, 376)
# (4, 377)
# (3, 378)
# (2, 379)
# (1, 380)
# (5, 381)
# (3, 382)
# (5, 383)
# (3, 384)
# (5, 385)
# (5, 386)
# (4, 387)
# (4, 388)
# (5, 389)
# (3, 390)
# (3, 391)
# (2, 392)
# (7, 393)
# (4, 394)
# (1, 395)
# (5, 396)
# (5, 397)
# (4, 398)
# (5, 399)
# (5, 400)
# (3, 401)
# (5, 402)
# (2, 403)
# (7, 404)
# (3, 405)
# (9, 406)
# (4, 407)
# (5, 408)
# (5, 409)
# (5, 410)
# (5, 411)
# (1, 412)
# (2, 413)
# (3, 414)
# (4, 415)
# (4, 416)
# (1, 417)
# (4, 418)
# (5, 419)
# (5, 420)
# (6, 421)
# (1, 422)
# (3, 423)
# (4, 424)
# (4, 425)
# (4, 426)
# (4, 427)
# (1, 428)
# (14, 429)
# (15, 430)
# (5, 431)
# (5, 432)
# (5, 433)
# (5, 434)
# (3, 435)
# (1, 436)
# (16, 437)
# (5, 438)
# (3, 439)
# (5, 440)
# (4, 441)
# (5, 442)
# (5, 443)
# (1, 444)
# (4, 445)
# (2, 446)
# (4, 447)
# (7, 448)
# (8, 449)
# (1, 450)
# (4, 451)
# (1, 452)
# (5, 453)
# (4, 454)
# (4, 455)
# (4, 456)
# (8, 457)
# (8, 458)
# (1, 459)
# (2, 460)
# (2, 461)
# (3, 462)
# (5, 463)
# (5, 464)
# (3, 465)
# (2, 466)
# (4, 467)
# (1, 468)
# (5, 469)
# (1, 470)
# (1, 471)
# (16, 472)
# (4, 473)
# (3, 474)
# (4, 475)
# (4, 476)
# (5, 477)
# (4, 478)
# (9, 479)
# (4, 480)
# (4, 481)
# (1, 482)
# (6, 483)
# (5, 484)
# (5, 485)
# (4, 486)
# (4, 487)
# (5, 488)
# (3, 489)
# (5, 490)
# (9, 491)
# (3, 492)
# (2, 493)
# (3, 494)
# (5, 495)
# (5, 496)
# (1, 497)
# (5, 498)
# (5, 499)
# (3, 500)
# (1, 501)
# (5, 502)
# (5, 503)
# (5, 504)
# (5, 505)
# (3, 506)
# (2, 507)
# (1, 508)
# (5, 509)
# (4, 510)
# (2, 511)
# (4, 512)
# (4, 513)
# (11, 514)
# (3, 515)
# (1, 516)
# (3, 517)
# (1, 518)
# (3, 519)
# (5, 520)
# (1, 521)
# (4, 522)
# (1, 523)
# (4, 524)
# (5, 525)
# (5, 526)
# (5, 527)
# (4, 528)
# (4, 529)
# (4, 530)
# (9, 531)
# (3, 532)
# (14, 533)
# (3, 534)
# (4, 535)
# (4, 536)
# (1, 537)
# (1, 538)
# (5, 539)
# (4, 540)
# (4, 541)
# (1, 542)
# (2, 543)
# (3, 544)
# (1, 545)
# (5, 546)
# (5, 547)
# (1, 548)
# (5, 549)
# (5, 550)
# (4, 551)
# (4, 552)
# (1, 553)
# (1, 554)
# (3, 555)
# (14, 556)
# (5, 557)
# (1, 558)
# (4, 559)
# (2, 560)
# (5, 561)
# (1, 562)
# (5, 563)
# (3, 564)
# (4, 565)
# (4, 566)
# (17, 567)
# (5, 568)
# (5, 569)
# (1, 570)
# (1, 571)
# (1, 572)
# (5, 573)
# (5, 574)
# (14, 575)
# (9, 576)
# (5, 577)
# (7, 578)
# (4, 579)
# (14, 580)
# (4, 581)
# (1, 582)
# (4, 583)
# (4, 584)
# (7, 585)
# (1, 586)
# (5, 587)
# (5, 588)
# (3, 589)
# (3, 590)
# (5, 591)
# (4, 592)
# (15, 593)
# (5, 594)
# (5, 595)
# (5, 596)
# (5, 597)
# (4, 598)
# (4, 599)
# (1, 600)
# (1, 601)
# (2, 602)
# (7, 603)
# (4, 604)
# (7, 605)
# (9, 606)
# (5, 607)
# (5, 608)
# (2, 609)
# (5, 610)
# (4, 611)
# (4, 612)
# (4, 613)
# (4, 614)
# (3, 615)
# (4, 616)
# (1, 617)
# (7, 618)
# (2, 619)
# (1, 620)
# (5, 621)
# (4, 622)
# (17, 623)
# (1, 624)
# (5, 625)
# (14, 626)
# (5, 627)
# (3, 628)
# (4, 629)
# (3, 630)
# (4, 631)
# (5, 632)
# (5, 633)
# (3, 634)
# (3, 635)
# (4, 636)
# (5, 637)
# (5, 638)
# (4, 639)
# (5, 640)
# (1, 641)
# (5, 642)
# (3, 643)
# (2, 644)
# (5, 645)
# (2, 646)
# (13, 647)
# (9, 648)
# (5, 649)
# (3, 650)
# (2, 651)
# (4, 652)
# (7, 653)
# (1, 654)
# (9, 655)
# (4, 656)
# (4, 657)
# (5, 658)
# (4, 659)
# (4, 660)
# (5, 661)
# (5, 662)
# (1, 663)
# (7, 664)
# (9, 665)
# (4, 666)
# (1, 667)
# (9, 668)
# (2, 669)
# (8, 670)
# (5, 671)
# (5, 672)
# (5, 673)
# (1, 674)
# (7, 675)
# (3, 676)
# (1, 677)
# (18, 678)
# (2, 679)
# (7, 680)
# (3, 681)
# (4, 682)
# (1, 683)
# (5, 684)
# (4, 685)
# (1, 686)
# (4, 687)
# (1, 688)
# (5, 689)
# (2, 690)
# (5, 691)
# (1, 692)
# (5, 693)
# (9, 694)
# (2, 695)
# (5, 696)
# (3, 697)
# (9, 698)
# (1, 699)
# (4, 700)
# (5, 701)
# (5, 702)
# (5, 703)
# (5, 704)
# (4, 705)
# (2, 706)
# (5, 707)
# (5, 708)
# (1, 709)
# (5, 710)
# (4, 711)
# (4, 712)
# (3, 713)
# (4, 714)
# (5, 715)
# (4, 716)
# (5, 717)
# (14, 718)
# (1, 719)
# (5, 720)
# (1, 721)
# (5, 722)
# (4, 723)
# (7, 724)
# (5, 725)
# (4, 726)
# (4, 727)
# (4, 728)
# (1, 729)
# (2, 730)
# (4, 731)
# (1, 732)
# (2, 733)
# (5, 734)
# (5, 735)
# (1, 736)
# (4, 737)
# (7, 738)
# (2, 739)
# (4, 740)
# (4, 741)
# (9, 742)
# (5, 743)
# (5, 744)
# (2, 745)
# (15, 746)
# (1, 747)
# (4, 748)
# (1, 749)
# (5, 750)
# (1, 751)
# (3, 752)
# (5, 753)
# (3, 754)
# (5, 755)
# (1, 756)
# (1, 757)
# (4, 758)
# (2, 759)
# (5, 760)
# (4, 761)
# (16, 762)
# (3, 763)
# (4, 764)
# (2, 765)
# (3, 766)
# (4, 767)
# (15, 768)
# (2, 769)
# (4, 770)
# (15, 771)
# (9, 772)
# (4, 773)
# (1, 774)
# (3, 775)
# (5, 776)
# (2, 777)
# (13, 778)
# (3, 779)
# (4, 780)
# (3, 781)
# (9, 782)
# (5, 783)
# (5, 784)
# (7, 785)
# (7, 786)
# (5, 787)
# (2, 788)
# (4, 789)
# (3, 790)
# (12, 791)
# (5, 792)
# (5, 793)
# (0, 794)
# (5, 795)
# (3, 796)
# (4, 797)
# (5, 798)
# (4, 799)
# (1, 800)
# (3, 801)
# (4, 802)
# (4, 803)
# (4, 804)
# (1, 805)
# (9, 806)
# (1, 807)
# (4, 808)
# (5, 809)
# (1, 810)
# (7, 811)
# (15, 812)
# (4, 813)
# (4, 814)
# (5, 815)
# (13, 816)
# (1, 817)
# (4, 818)
# (4, 819)
# (5, 820)
# (9, 821)
# (5, 822)
# (7, 823)
# (5, 824)
# (9, 825)
# (3, 826)
# (4, 827)
# (2, 828)
# (2, 829)
# (13, 830)
# (5, 831)
# (3, 832)
# (5, 833)
# (5, 834)
# (4, 835)
# (3, 836)
# (9, 837)
# (5, 838)
# (3, 839)
# (3, 840)
# (4, 841)
# (1, 842)
# (4, 843)
# (1, 844)
# (4, 845)
# (1, 846)
# (3, 847)
# (1, 848)
# (1, 849)
# (1, 850)
# (3, 851)
# (4, 852)
# (5, 853)
# (3, 854)
# (4, 855)
# (3, 856)
# (1, 857)
# (4, 858)
# (5, 859)
# (5, 860)
# (1, 861)
# (9, 862)
# (5, 863)
# (4, 864)
# (1, 865)
# (9, 866)
# (5, 867)
# (2, 868)
# (4, 869)
# (5, 870)
# (5, 871)
# (9, 872)
# (5, 873)
# (15, 874)
# (4, 875)
# (3, 876)
# (11, 877)
# (4, 878)
# (1, 879)
# (1, 880)
# (1, 881)
# (3, 882)
# (5, 883)
# (4, 884)
# (1, 885)
# (4, 886)
# (3, 887)
# (2, 888)
# (5, 889)
# (1, 890)
# (1, 891)
# (15, 892)
# (5, 893)
# (7, 894)
# (9, 895)
# (4, 896)
# (1, 897)
# (4, 898)
# (4, 899)
# (4, 900)
# (3, 901)
# (4, 902)
# (5, 903)
# (5, 904)
# (18, 905)
# (1, 906)
# (2, 907)
# (5, 908)
# (18, 909)
# (4, 910)
# (1, 911)
# (5, 912)
# (1, 913)
# (2, 914)
# (5, 915)
# (1, 916)
# (7, 917)
# (4, 918)
# (7, 919)
# (4, 920)
# (1, 921)
# (1, 922)
# (9, 923)
# (5, 924)
# (4, 925)
# (5, 926)
# (1, 927)
# (4, 928)
# (1, 929)
# (5, 930)
# (1, 931)
# (1, 932)
# (5, 933)
# (9, 934)
# (1, 935)
# (4, 936)
# (7, 937)
# (4, 938)
# (4, 939)
# (1, 940)
# (3, 941)
# (2, 942)
# (9, 943)
# (5, 944)
# (5, 945)
# (4, 946)
# (5, 947)
# (4, 948)
# (2, 949)
# (1, 950)
# (4, 951)
# (9, 952)
# (3, 953)
# (5, 954)
# (4, 955)
# (4, 956)
# (1, 957)
# (4, 958)
# (2, 959)
# (9, 960)
# (5, 961)
# (2, 962)
# (9, 963)
# (1, 964)
# (4, 965)
# (4, 966)
# (1, 967)
# (4, 968)
# (5, 969)
# (4, 970)
# (4, 971)
# (4, 972)
# (9, 973)
# (3, 974)
# (1, 975)
# (5, 976)
# (3, 977)
# (1, 978)
# (3, 979)
# (4, 980)
# (9, 981)
# (5, 982)
# (17, 983)
# (9, 984)
# (4, 985)
# (1, 986)
# (5, 987)
# (4, 988)
# (4, 989)
# (1, 990)
# (1, 991)
# (5, 992)
# (5, 993)
# (4, 994)
# (3, 995)
# (1, 996)
# (2, 997)
# (3, 998)
# (1, 999)
# (2, 1000)
# (1, 1001)
# (4, 1002)
# (1, 1003)
# (9, 1004)
# (1, 1005)
# (1, 1006)
# (1, 1007)
# (1, 1008)
# (1, 1009)
# (4, 1010)
# (1, 1011)
# (1, 1012)
# (1, 1013)
# (1, 1014)
# (9, 1015)
# (1, 1016)
# (5, 1017)
# (9, 1018)
# (1, 1019)
# (4, 1020)
# (9, 1021)
# (1, 1022)
# (1, 1023)
# (4, 1024)
# (1, 1025)
# (1, 1026)
# (1, 1027)
# (4, 1028)
# (1, 1029)
# (1, 1030)
# (2, 1031)
# (7, 1032)
# (1, 1033)
# (1, 1034)
# (1, 1035)
# (1, 1036)
# (9, 1037)
# (4, 1038)
# (1, 1039)
# (5, 1040)
# (12, 1041)
# (9, 1042)
# (5, 1043)
# (1, 1044)
# (1, 1045)
# (1, 1046)
# (7, 1047)
# (5, 1048)
# (3, 1049)
# (5, 1050)
# (1, 1051)
# (4, 1052)
# (1, 1053)
# (4, 1054)
# (1, 1055)
# (1, 1056)
# (2, 1057)
# (4, 1058)
# (7, 1059)
# (1, 1060)
# (3, 1061)
# (4, 1062)
# (4, 1063)
# (7, 1064)
# (4, 1065)
# (3, 1066)
# (4, 1067)
# (4, 1068)
# (0, 1069)
# (4, 1070)
# (1, 1071)
# (1, 1072)
# (1, 1073)
# (5, 1074)
# (5, 1075)
# (5, 1076)
# (7, 1077)
# (5, 1078)
# (1, 1079)
# (5, 1080)
# (5, 1081)
# (5, 1082)
# (1, 1083)
# (4, 1084)
# (1, 1085)
# (1, 1086)
# (5, 1087)
# (1, 1088)
# (2, 1089)
# (4, 1090)
# (1, 1091)
# (3, 1092)
# (4, 1093)
# (1, 1094)
# (2, 1095)
# (4, 1096)
# (7, 1097)
# (1, 1098)
# (3, 1099)
# (4, 1100)
# (4, 1101)
# (2, 1102)
# (1, 1103)
# (5, 1104)
# (4, 1105)
# (7, 1106)
# (5, 1107)
# (1, 1108)
# (3, 1109)
# (1, 1110)
# (4, 1111)
# (5, 1112)
# (1, 1113)
# (5, 1114)
# (4, 1115)
# (5, 1116)
# (13, 1117)
# (9, 1118)
# (3, 1119)
# (12, 1120)
# (1, 1121)
# (1, 1122)
# (4, 1123)
# (3, 1124)
# (5, 1125)
# (5, 1126)
# (1, 1127)
# (5, 1128)
# (1, 1129)
# (1, 1130)
# (5, 1131)
# (3, 1132)
# (1, 1133)
# (2, 1134)
# (5, 1135)
# (1, 1136)
# (4, 1137)
# (7, 1138)
# (1, 1139)
# (5, 1140)
# (7, 1141)
# (1, 1142)
# (1, 1143)
# (1, 1144)
# (1, 1145)
# (1, 1146)
# (4, 1147)
# (1, 1148)
# (5, 1149)
# (5, 1150)
# (1, 1151)
# (5, 1152)
# (4, 1153)
# (4, 1154)
# (1, 1155)
# (7, 1156)
# (5, 1157)
# (5, 1158)
# (1, 1159)
# (5, 1160)
# (7, 1161)
# (1, 1162)
# (5, 1163)
# (1, 1164)
# (4, 1165)
# (5, 1166)
# (5, 1167)
# (1, 1168)
# (7, 1169)
# (1, 1170)
# (1, 1171)
# (3, 1172)
# (5, 1173)
# (5, 1174)
# (3, 1175)
# (5, 1176)
# (5, 1177)
# (7, 1178)
# (1, 1179)
# (5, 1180)
# (5, 1181)
# (4, 1182)
# (2, 1183)
# (1, 1184)
# (3, 1185)
# (4, 1186)
# (2, 1187)
# (4, 1188)
# (2, 1189)
# (5, 1190)
# (15, 1191)
# (1, 1192)
# (0, 1193)
# (4, 1194)
# (1, 1195)
# (5, 1196)
# (3, 1197)
# (2, 1198)
# (7, 1199)
# (4, 1200)
# (5, 1201)
# (4, 1202)
# (4, 1203)
# (3, 1204)
# (4, 1205)
# (1, 1206)
# (5, 1207)
# (2, 1208)
# (3, 1209)
# (0, 1210)
# (3, 1211)
# (7, 1212)
# (4, 1213)
# (3, 1214)
# (2, 1215)
# (2, 1216)
# (5, 1217)
# (5, 1218)
# (2, 1219)
# (5, 1220)
# (7, 1221)
# (1, 1222)
# (4, 1223)
# (4, 1224)
# (3, 1225)
# (4, 1226)
# (4, 1227)
# (5, 1228)
# (7, 1229)
# (5, 1230)
# (13, 1231)
# (4, 1232)
# (7, 1233)
# (0, 1234)
# (1, 1235)
# (1, 1236)
# (4, 1237)
# (7, 1238)
# (5, 1239)
# (5, 1240)
# (3, 1241)
# (2, 1242)
# (4, 1243)
# (1, 1244)
# (3, 1245)
# (4, 1246)
# (3, 1247)
# (5, 1248)
# (4, 1249)
# (4, 1250)
# (1, 1251)
# (5, 1252)
# (5, 1253)
# (4, 1254)
# (3, 1255)
# (3, 1256)
# (4, 1257)
# (5, 1258)
# (7, 1259)
# (5, 1260)
# (3, 1261)
# (4, 1262)
# (2, 1263)
# (4, 1264)
# (5, 1265)
# (1, 1266)
# (4, 1267)
# (1, 1268)
# (3, 1269)
# (5, 1270)
# (5, 1271)
# (5, 1272)
# (1, 1273)
# (3, 1274)

# %% [markdown]
#  QUESTION 4 (5 points)
#  ----------------------------------------------------
#      Write the Python or R code that creates a view and queries the database to displays the average
#      laptop price (euros) per company
#      (select * from <your view name>)

# %%
create_view_for_AVG_price_of_company = """
    Create view view_for_AVG_price_of_company as
    SELECT company_name,AVG(product."Price_euros") from
    company INNER JOIN company_have_product
    on company.company_id=company_have_product.company_id
    INNER JOIN product
    on product.product_id=company_have_product.product_id
    GROUP BY company_name;
"""
select_view_for_AVG_price_of_company = """
    SELECT * from view_for_AVG_price_of_company;
"""
Connection.execute(create_view_for_AVG_price_of_company)
result = Connection.execute(select_view_for_AVG_price_of_company)
for i in result:
    print(i)
# Out:
# ('Microsoft', 1612.30833333333)
# ('HP', 1080.3146641791)
# ('Razer', 3346.14285714286)
# ('Asus', 1123.82973684211)
# ('Google', 1677.66666666667)
# ('Huawei', 1424.0)
# ('MSI', 1728.90814814815)
# ('Lenovo', 1093.86221453287)
# ('Chuwi', 314.296666666667)
# ('Samsung', 1413.44444444444)
# ('LG', 2099.0)
# ('Vero', 217.425)
# ('Dell', 1199.22512027491)
# ('Xiaomi', 1133.4625)
# ('Mediacom', 295.0)
# ('Apple', 1564.19857142857)
# ('Fujitsu', 729.0)
# ('Toshiba', 1267.8125)
# ('Acer', 633.464455445545)

# %% [markdown]
#  QUESTION 5 (5 points)
#  -----------------------------------------------------
#
#  Provide either a Python or R code such that if the whole script is executed
#  once, then ALL the views and tables created by you for this exercise will be deleted in one go wihtout generating any error.
# 	Hint: A few objects you have created would have dependencies on other objects you have created
#
# 	SCORING RUBRIC
# 	**************
# 	2 points: Sequence of deletion is correct.
# 	3 points: Simply copy/pasting and executing the script provided in answer-6
# 				deletes ALL the database objects created in all the above answeres, without any error
# 			*even a minor (including syntax) error will not get you this 1 point

# %%
DROP_ALL = """
    ALTER TABLE company_have_product DROP CONSTRAINT company_have_product_fkey_company;
    ALTER TABLE company_have_product DROP CONSTRAINT company_have_product_fkey_product;

    drop view company_view;
    drop view view_for_avg_price_of_company;
    drop view product_view;
    drop view company_have_product_view;
    drop table company_have_product;
    drop table product;
    drop table company;
"""
Connection.execute(DROP_ALL)
